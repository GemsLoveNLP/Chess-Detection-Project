# %% [markdown]
# # AI boys: chess detection project
#
# **Members:**
# - Kridbhume Chammanard
# - Ting-Yi Lin
# - Thana Wanavit
# - Norapath Arjanurak
# - Pattaradanai Lakkananithiphan

# %% [markdown]
# ### Import the necessary libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import mediapipe as mp
from collections import Counter
import chess
import chess.pgn

import os
import random

from PIL import Image
from ultralytics import YOLO
from dotenv import dotenv_values
from ultralytics.utils.ops import scale_image

import json

# %% [markdown]
# ### Constant Settings

# %%
# initaiate hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(min_detection_confidence=0.2, min_tracking_confidence=0.5)
# a to h from left to right
X_INDEX = list("abcdefgh")
# 8 to 1 from top to bottom
Y_INDEX = [str(i+1) for i in range(8)][::-1]
# initiate state accumulation variables
state_list = []
pgn_list = []
# noise frame tolerance
TOLERANCE = 2
# crop distance
CROP = 50
# 1/frame_rate
RATE = 15
# class names
BLACK = "black"
WHITE = "white"
KING = "king"
# promotion key for uci
PROMOTE_KEY = {"knight":"n","king":"k","bishop":"b","queen":"q","rook":"r","pawn":""}
SYM_KEY = {"knight":"n","king":"k","bishop":"b","queen":"q","rook":"r","pawn":"p"}
# Out:
# W0000 00:00:1733758418.394035    9557 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1733758418.406334    9557 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %% [markdown]
# ### Model Inference

# %%
class ChessPredicter:
    def __init__(self, model_path="./chess_model/runs/detect/chess_data_model/weights/best.pt"):
      model = YOLO(model_path)
      self.model = model

    def predict_image(self, img):
      results = self.model(img)[0]
      return results.to_json()
    
    def format_output(self, result):
      lst = json.loads(result)
      # reformat as class, x, y, w, h
      return [(e['name'],e['box']['x1'],e['box']['y1'],e['box']['x2']-e['box']['x1'],e['box']['y2']-e['box']['y1']) for e in lst]
    
    def get_state(self, img):
       result = self.predict_image(img)
       return self.format_output(result)

# %%
img = cv2.imread("Screenshot 2024-11-25 124759.png")[:,:,::-1]
# initialize predictor model
chess_predictor = ChessPredicter()
res = chess_predictor.predict_image(img)
res = json.loads(res)
print(res[0])
[(e['name'],e['box']['x1'],e['box']['y1'],e['box']['x2']-e['box']['x1'],e['box']['y2']-e['box']['y1']) for e in res][0]
# Out:
# 0: 416x416 1 black-rook, 6 white-rooks, 12.7ms
# Speed: 2.5ms preprocess, 12.7ms inference, 0.7ms postprocess per image at shape (1, 3, 416, 416)
# {'name': 'white-rook', 'class': 12, 'confidence': 0.73088, 'box': {'x1': 574.62781, 'y1': 169.42317, 'x2': 645.1496, 'y2': 222.27263}}
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1733757265.458153    8465 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1733757265.471021    8465 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ('white-rook', 574.62781, 169.42317, 70.52179000000001, 52.84945999999999)

# %% [markdown]
# ### Image preprocessing

# %%
class ChessboardProcessor:

    WIDTH = 640
    HEIGHT = 640

    def __init__(self, image):
        # self.image_path = image_path
        self.image = image
        self.warped_image = None
        self.transformation_matrix = None

    # Utility function to display images
    def display_image(self, img, title="Image"):
        plt.figure(figsize=(6, 6))
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.title(title)
        plt.show()

    # Reorders points to top-left, top-right, bottom-right, bottom-left
    def reorder(self, pts):
        pts = pts.reshape((4, 2))
        new_pts = np.zeros((4, 1, 2), dtype="float32")
        sum_pts = pts.sum(1)
        new_pts[0] = pts[np.argmin(sum_pts)]  # Top-left
        new_pts[3] = pts[np.argmax(sum_pts)]  # Bottom-right
        diff_pts = np.diff(pts, axis=1)
        new_pts[1] = pts[np.argmin(diff_pts)]  # Top-right
        new_pts[2] = pts[np.argmax(diff_pts)]  # Bottom-left
        return new_pts

    # Preprocess the image (grayscale, blur, threshold, morphology)
    def preprocess(self):
        img_gray = cv2.cvtColor(self.image, cv2.COLOR_BGR2GRAY)
        img_blur = cv2.GaussianBlur(img_gray, (3, 3), 1)
        img_threshold = cv2.adaptiveThreshold(img_blur, 255, 1, 1, 15, 2)

        # Morphological operations
        # kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
        # img_opening = cv2.morphologyEx(img_threshold, cv2.MORPH_OPEN, kernel)
        # img_closing = cv2.morphologyEx(img_opening, cv2.MORPH_CLOSE, kernel)

        # self.display_image(img_threshold, "Preprocessed Image")
        return img_threshold

    # Finds the largest contour with 4 points
    def find_biggest_contour(self, contours):
        largest_pts = None
        max_area = 0
        for contour in contours:
            area = cv2.contourArea(contour)
            if area > 50:  # Ignore small contours
                peri = cv2.arcLength(contour, True)
                approx = cv2.approxPolyDP(contour, 0.1 * peri, True)
                if area > max_area and len(approx) == 4:
                    largest_pts = approx
                    max_area = area
        return self.reorder(largest_pts) if largest_pts is not None else None, max_area

    # Finds the chessboard corners and returns the reordered corners
    def find_board_corners(self):
        processed_img = self.preprocess()
        contours, _ = cv2.findContours(processed_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        contour_img = self.image.copy()
        cv2.drawContours(contour_img, contours, -1, (0, 255, 0), 3)
        # self.display_image(contour_img, "Image with Contours")
        corners, _ = self.find_biggest_contour(contours)
        return corners

    # Applies perspective transformation to get a bird's-eye view
    def warp_image(self, corners):
        original_pts = np.float32(corners)
        new_pts = np.float32([[0, 0], [self.WIDTH, 0], [0, self.HEIGHT], [self.WIDTH, self.HEIGHT]])
        self.transformation_matrix = cv2.getPerspectiveTransform(original_pts, new_pts)
        self.warped_image = cv2.warpPerspective(self.image, self.transformation_matrix, (self.WIDTH, self.HEIGHT))
        return self.warped_image

    # Draws points on the given image
    def draw_points(self, img, pts, color=(0, 0, 255), size=10):
        for pt in pts:
            pt = tuple(map(int, pt))  # Convert to (x, y) tuple
            cv2.circle(img, pt, size, color, -1)

    # Generates random points within the image dimensions
    def generate_random_points(self, num_points=4):
        height, width, _ = self.image.shape
        
        # Generate random points
        random_points = [(random.randint(0, width - 1), random.randint(0, height - 1)) for _ in range(num_points)]
        random_points = np.float32(random_points)
        
        # Create a list of tuples with (piece, x_coord, y_coord)
        piece_list = []
        for i, (x_coord, y_coord) in enumerate(random_points, start=1):
            piece_list.append((f"piece {i}", x_coord, y_coord))
        
        return piece_list
    
    # Main function to process the image
    def rotate_and_warp(self, detection_cg):
        # Find the chessboard corners in the frame
        corners = self.find_board_corners()
        if corners is not None:
            # Copy the original image for visualization
            image_with_points = self.image.copy()

            # Draw the original detection CG points on the original image
            for piece, x_coord, y_coord in detection_cg:
                self.draw_points(image_with_points, [(x_coord, y_coord)])

            # Warp the image based on the detected chessboard corners
            warped_image = self.warp_image(corners)

            # Prepare the original detection CG points for transformation
            original_points = np.array([[x, y] for _, x, y in detection_cg], dtype=np.float32).reshape(-1, 1, 2)

            # Apply perspective transformation to the original points
            transformed_points = cv2.perspectiveTransform(original_points, self.transformation_matrix)

            # Prepare the transformed points as a list of tuples (piece, x_new, y_new)
            transformed_points_list = []
            for i, (piece, _, _) in enumerate(detection_cg):  # Correct unpacking here
                x_new, y_new = transformed_points[i][0]
                transformed_points_list.append((piece, x_new, y_new))

            # Draw the transformed points on the warped image
            self.draw_points(warped_image, transformed_points[:, 0])

            # Display the original image with points and the warped image with transformed points
            # plt.figure(figsize=(12, 6))
            # plt.subplot(1, 2, 1)
            # plt.imshow(cv2.cvtColor(image_with_points, cv2.COLOR_BGR2RGB))
            # plt.title("Original Image with Detection Points")
            # plt.axis('off')

            # plt.subplot(1, 2, 2)
            # plt.imshow(cv2.cvtColor(warped_image, cv2.COLOR_BGR2RGB))
            # plt.title("Warped Image with Transformed Points")
            # plt.axis('off')

            # plt.show()

            return warped_image, transformed_points_list
        else:
            print("Could not find the corners of the chessboard.")
            return None, None

# %% [markdown]
# ### Program loop

# %%
# wrap the video reader
def frame_generator(video_path):
    # Open the video file
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print("Error: Could not open video file.")
        return

    while True:
        ret, frame = cap.read()
        if not ret:
            break  # End of video
        yield frame  # Yield frame to the caller

    cap.release()

# Function to check if hands are detected in a frame
def hands_detected(frame):
    # Convert the frame to RGB as MediaPipe uses RGB
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    
    # Process the frame and get the result
    results = hands.process(rgb_frame)
    
    # If hands are detected, results.multi_hand_landmarks will not be None
    return results.multi_hand_landmarks is not None

# summarize state list into easy to use format
def summarize_states(lst, tolerance):

    # Step 1: Clean the state list of noises
    # initialize counters
    state_counter = 1
    previous = None
    updated = False
    summarized_states = []
    # loop through the list
    for state in lst:

        # if new state detected
        if previous is None or state != previous:
            state_counter = 1
            updated = False

        # if the count of state reaches tolerance
        if state_counter >= tolerance and not updated:
            # print("Noted")
            summarized_states.append(state)
            updated = True

        # print(f"state = {state}\nprevious = {previous}\nstate_counter={state_counter}\nupdated={updated}","\n")

        # iterate the counters
        state_counter += 1
        previous = state
    # print(f"Summarized:", summarized_states)

    # Step 2: Identify differences between consecutive states
    differences = []
    for i in range(len(summarized_states) - 1):
        old_state = summarized_states[i]
        new_state = summarized_states[i + 1]
        
        disappeared = old_state - new_state
        appeared = new_state - old_state
        
        differences.append((disappeared, appeared))
    # print("Differences:", differences)

    return differences

def uci_from_differences(differences):

    """
    Convert the output of summarize_states into UCI format.

    Parameters:
        differences (list): List of differences as ({disappeared}, {appeared}).

    Returns:
        list: A list of UCI moves
    """

    uci_moves = []

    for disappeared, appeared in differences:

        l_d = len(disappeared)
        l_a = len(appeared)

        if l_d == 1 and l_a == 1: # movement or promotion

            old = list(disappeared)[0]
            new = list(appeared)[0]

            if old[:2] == new[:2]: # if the class and color is the same -> movement
                msg = f"{old[2]}{old[3]}{new[2]}{new[3]}"

            else: # promotion
                msg = f"{old[2]}{old[3]}{new[2]}{new[3]}{PROMOTE_KEY[new[1]]}"

        elif l_d == 2 and l_a == 1: # capturing

            new = list(appeared)[0]
            old = [piece for piece in disappeared if piece[:2] == new[:2]][0] # the capturer

            msg = f"{old[2]}{old[3]}{new[2]}{new[3]}"

        elif l_d == 2 and l_d == 2: # castling

            new_king = [piece for piece in appeared if piece[:2] == KING][0]

            if new_king[2] == "g": # king side
                if new_king[0] == BLACK:
                    msg = "e8g8"
                else:
                    msg = "e1g1"
            elif new_king[2] == "c": # queen side
                if new_king[0] == BLACK:
                    msg = "e8c8"
                else:
                    msg = "e1c1"
            else:
                msg = "CASTLING_ERROR"

        else:

            msg = "MOVE_ERROR"

        uci_moves.append(msg)
     
    return uci_moves

def generate_pgn(moves, ori):

    """
    Convert UCI moves on a board to PGN and also output board state 

    Parameters:
        moves (list) : List of UCI moves in the game
        ori (list) : List of pieces on the board. Each piece is structured as (color, class, alphabet, num)

    Returns:
        pgn (str) : A string of PGN of the game
        board_states (list) : a list of board states. Each state is a string
    
    """

    # initialize board
    board = chess.Board()

    # if there is a predetermined starting point
    if ori is not None:
        board.clear()

        # place each piece
        for color, piece, alpha, num in ori:

            sym = SYM_KEY[piece]

            if color == BLACK:
                piece = sym.lower()
            elif color == WHITE:
                piece = sym.upper()

            position = alpha + str(num)
            square = chess.parse_square(position)
            board.set_piece_at(square, chess.Piece.from_symbol(sym))

    # create game
    game = chess.pgn.Game()
    node = game
    node.headers["FEN"] = board.fen()

    # iterate through UCI and keep track of board state
    board_states = list()
    board_states.append(board)
    for move in moves:
        try:
            node = node.add_variation(board.parse_uci(move))
            board.push_uci(move)
            board_states.append(board)
        except ValueError:
            print(f"Move {move} is invalid")
    
    pgn = str(game).split("\n")[-1]
    return pgn, board_states

# main
def main(video_path):

    predictor = ChessPredicter()

    for i, frame in enumerate(frame_generator(video_path)):
            
        if i % RATE == 0:

            frame = frame[:,:,::-1]

            h,w,_ = frame.shape
            delta = (h-w)//2
            frame = frame[delta+CROP:delta+w-CROP,:,:]

            # plt.imshow(frame)
            # plt.show()

            # if hand is there
            if not hands_detected(frame):

                # detect pieces and format the piece's foot CG
                detection = predictor.get_state(frame)
                detection_cg = {(piece_class,x+w//2,y+h) for piece_class,x,y,w,h in detection}
                print(detection_cg)

                # get the transformed image and the coordinate of the transformed CG
                chessboard = ChessboardProcessor(frame)
                img, piece_cg = chessboard.rotate_and_warp(detection_cg)
                if img is None or piece_cg is None: # if the frame is bad skip it
                    continue
                print(piece_cg[0][1])

                # get the image size to divide into cells
                shape = img.shape
                x_cell_size = shape[0]//8
                y_cell_size = shape[1]//8
                x = piece_cg[0][1]
                print(x, x_cell_size, x//x_cell_size)
                

                # img, {(white-knight,x,y),(black-queen,x1,y1)}

                # reformat the piece_cg set to indicate row and column instead
                detection_cell = {(piece_class.split("-")[0], # color
                                piece_class.split("-")[1], # class
                                X_INDEX[int(x//x_cell_size) % 8], # column: a,b,c..
                                Y_INDEX[int(y//y_cell_size) % 8]) # row: 1,2,...
                                for piece_class,x,y in piece_cg}
                
                state_list.append(detection_cell)

    # Original state
    ori = state_list[0]
        
    # Once the processing is finished
    differences = summarize_states(lst=state_list, tolerance=TOLERANCE)
    uci = uci_from_differences(differences)
    pgn, board_states = generate_pgn(moves=uci, ori=ori)

    return pgn, board_states

# %%
main("2_move_student.mp4")
# Out:
# 0: 384x416 2 black-knights, 3 black-pawns, 2 black-rooks, 1 white-king, 2 white-knights, 3 white-pawns, 2 white-queens, 6 white-rooks, 12.8ms
# Speed: 3.7ms preprocess, 12.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 416)
# {('white-rook', 472.97192, 454.108), ('white-rook', 155.14787, 246.44955), ('black-knight', 246.65712, 894.45459), ('white-pawn', 258.42331, 248.33685), ('white-rook', 811.2453, 459.39157), ('black-pawn', 840.53699, 782.03894), ('black-knight', 935.87988, 568.62061), ('white-rook', 925.12103, 145.92099), ('white-knight', 701.56866, 369.3295), ('black-rook', 979.03412, 890.58624), ('black-rook', 951.36737, 785.20013), ('black-pawn', 599.92047, 667.20276), ('white-queen', 370.82669, 255.59462), ('white-rook', 702.47412, 369.66919), ('white-rook', 158.08652, 135.09654), ('black-pawn', 492.75772, 566.12781), ('white-queen', 598.58026, 156.84891), ('white-pawn', 597.75787, 558.41248), ('white-king', 372.61322, 256.99805), ('white-pawn', 724.10126, 248.44273), ('white-knight', 108.18697, 890.92474)}
# 1525.4086
# 1525.4086 80 19.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 2 black-rooks, 1 white-king, 2 white-knights, 3 white-pawns, 2 white-queens, 7 white-rooks, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-queen', 370.61813, 256.11945), ('black-pawn', 840.33765, 781.91644), ('black-pawn', 599.95953, 667.28912), ('black-pawn', 712.83002, 791.40057), ('white-king', 371.66122, 256.46426), ('white-rook', 924.46332, 146.26157), ('white-rook', 811.56238, 459.72897), ('black-knight', 246.64317, 894.383), ('white-knight', 109.25074, 891.12463), ('black-rook', 978.84686, 891.03558), ('black-rook', 951.35547, 785.30585), ('white-rook', 702.57861, 370.40997), ('white-rook', 473.24313, 454.71896), ('white-rook', 599.52979, 557.86426), ('white-pawn', 258.08349999999996, 249.00362), ('white-pawn', 724.0014, 248.60805), ('black-knight', 936.48206, 568.65674), ('white-queen', 599.46649, 157.19019), ('white-knight', 702.92548, 370.87369), ('white-pawn', 598.11365, 558.26746), ('white-rook', 157.88655, 135.14685), ('white-rook', 154.28463, 247.08342), ('black-pawn', 492.58636, 566.35938)}
# 305.86313
# 305.86313 80 3.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 2 black-rooks, 1 white-king, 2 white-knights, 3 white-pawns, 2 white-queens, 7 white-rooks, 12.4ms
# Speed: 4.0ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-pawn', 597.90741, 558.43115), ('black-pawn', 492.41498, 566.37091), ('white-pawn', 723.94373, 248.53975), ('white-queen', 370.55313, 256.2153), ('white-rook', 811.26971, 459.8688), ('black-rook', 978.62909, 890.82703), ('black-pawn', 599.83331, 667.44519), ('white-pawn', 258.27696000000003, 248.85286), ('white-knight', 702.22919, 370.14789), ('black-pawn', 712.64142, 791.52136), ('white-rook', 472.95642, 455.17249), ('white-rook', 115.04693, 892.51178), ('white-knight', 107.87856, 891.04407), ('black-knight', 936.60571, 568.49854), ('black-pawn', 840.11371, 781.97791), ('black-rook', 951.09039, 785.25195), ('white-rook', 702.12048, 370.22818), ('white-king', 372.59552, 257.80292), ('white-rook', 154.07560999999998, 247.20891), ('white-queen', 599.00244, 157.42967), ('white-rook', 924.39185, 147.0247), ('black-knight', 247.17274, 894.07288), ('white-rook', 156.9649, 135.31851)}
# -331.36563
# -331.36563 80 -5.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 2 black-rooks, 1 white-king, 1 white-knight, 2 white-pawns, 2 white-queens, 6 white-rooks, 12.5ms
# Speed: 4.0ms preprocess, 12.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-pawn', 598.09467, 559.41272), ('white-knight', 108.67633, 891.53595), ('black-rook', 978.99768, 891.26959), ('black-knight', 247.45746, 894.25684), ('white-rook', 154.1211, 247.31488), ('black-pawn', 599.36145, 667.94141), ('white-king', 372.41891, 257.83344), ('white-queen', 370.5065, 255.86784), ('black-pawn', 711.85577, 791.66644), ('white-rook', 115.61824, 892.89618), ('white-rook', 473.50116, 455.67593), ('white-rook', 157.11668, 135.87744), ('black-pawn', 492.87903, 566.83624), ('white-pawn', 258.67470000000003, 248.56204), ('white-queen', 598.91992, 157.39389), ('white-rook', 810.84552, 460.14081), ('black-rook', 951.07538, 784.81519), ('black-knight', 936.07288, 569.04565), ('white-rook', 924.53955, 146.12405), ('black-pawn', 840.71869, 782.3877)}
# 1579.7502
# 1579.7502 80 19.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 2 black-rooks, 1 white-king, 1 white-knight, 4 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 3.6ms preprocess, 12.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 416)
# {('white-rook', 157.32846999999998, 136.03964), ('black-knight', 247.5341, 894.32336), ('white-queen', 598.73993, 157.4641), ('white-pawn', 258.29095, 248.75391), ('white-rook', 473.34848, 455.59491), ('white-pawn', 473.58734, 454.98514), ('black-pawn', 599.23199, 667.93091), ('black-knight', 936.03064, 568.84601), ('black-rook', 951.23065, 785.51105), ('white-knight', 109.50169, 891.4021), ('white-rook', 924.59119, 146.05638), ('black-pawn', 840.07898, 782.39771), ('white-rook', 115.46503, 892.77637), ('black-pawn', 712.61304, 792.10046), ('white-pawn', 724.49994, 248.50525), ('black-pawn', 492.73483, 566.73676), ('white-rook', 154.43491, 247.0862), ('white-pawn', 598.01184, 559.23962), ('white-queen', 370.95258, 255.93364), ('black-rook', 978.71533, 891.19104), ('white-king', 372.77603, 257.83215), ('white-rook', 810.99927, 459.94211)}
# -2929.712
# -2929.712 80 -37.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 2 black-rooks, 1 white-king, 1 white-knight, 4 white-pawns, 2 white-queens, 4 white-rooks, 12.4ms
# Speed: 3.8ms preprocess, 12.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 416)
# {('white-pawn', 474.11984, 455.302), ('black-knight', 936.31866, 569.17902), ('white-pawn', 257.7914, 248.9118), ('black-rook', 951.39935, 785.48389), ('black-knight', 247.21767, 894.5202), ('black-pawn', 599.31, 668.41608), ('black-pawn', 840.03918, 783.77228), ('white-knight', 107.11454, 892.67023), ('black-pawn', 711.62811, 792.90259), ('white-king', 372.94565, 258.25888), ('white-queen', 370.19629, 256.53061), ('white-rook', 157.9102, 136.62573), ('white-rook', 154.20372, 247.72986), ('black-rook', 979.28839, 891.81036), ('black-pawn', 493.15228, 567.48456), ('white-pawn', 598.14813, 559.90948), ('white-rook', 923.66931, 146.67477), ('white-rook', 810.22357, 460.63538), ('white-queen', 599.01904, 157.61986), ('white-pawn', 724.70959, 248.53069)}
# -1037.213
# -1037.213 80 -13.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 1 black-queen, 2 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 711.60022, 791.98193), ('white-rook', 157.28825, 135.96536), ('black-queen', 605.59259, 898.83398), ('white-pawn', 257.79166, 248.69995), ('black-pawn', 492.42578, 567.02777), ('white-knight', 107.89178, 892.17102), ('black-pawn', 840.60803, 782.99445), ('white-king', 372.68665, 258.1337), ('white-rook', 810.53735, 460.28992), ('black-rook', 979.12128, 891.82214), ('white-rook', 473.72015, 455.93015), ('white-rook', 154.46922999999998, 247.25099), ('black-pawn', 599.28107, 668.15662), ('white-queen', 370.78519, 256.43271), ('black-rook', 951.28058, 785.19855), ('black-knight', 247.43205, 894.40613), ('black-knight', 936.36633, 569.07684), ('white-pawn', 473.88324, 455.10916), ('white-rook', 924.78265, 146.60445), ('white-rook', 114.55434, 893.32306), ('white-pawn', 724.81805, 248.54282), ('white-knight', 702.98358, 369.8801), ('white-queen', 599.12299, 157.33911), ('white-pawn', 598.18347, 559.66888)}
# 303.4136
# 303.4136 80 3.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 1 black-queen, 2 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 3.4ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-pawn', 474.04205, 455.29718), ('white-rook', 154.57772, 247.73911), ('black-queen', 489.78888, 904.44464), ('white-knight', 106.74365, 892.8811), ('white-rook', 114.44183, 893.94958), ('white-rook', 810.78552, 462.4339), ('white-rook', 924.83545, 146.83292), ('white-queen', 599.26648, 157.79083), ('black-pawn', 598.37817, 668.5827), ('black-rook', 979.68268, 891.64941), ('white-king', 372.40543, 258.44891), ('black-pawn', 839.88263, 783.9679), ('white-rook', 157.96771999999999, 136.24908), ('white-pawn', 598.38318, 559.55585), ('white-pawn', 258.15129, 248.98923), ('black-knight', 936.52686, 568.86877), ('black-knight', 246.95341, 894.83539), ('black-rook', 951.34772, 786.11047), ('white-rook', 473.8002, 456.06442), ('white-queen', 370.5701, 257.03168), ('white-knight', 703.55756, 369.7095), ('white-pawn', 724.60992, 248.55954), ('black-pawn', 492.40411, 567.25568), ('black-pawn', 711.30865, 793.21106)}
# -1074.5923
# -1074.5923 80 -14.0
#
# 0: 384x416 2 black-knights, 3 black-pawns, 1 black-queen, 2 black-rooks, 1 white-king, 2 white-knights, 3 white-pawns, 2 white-queens, 5 white-rooks, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-knight', 703.56458, 369.94046), ('black-pawn', 599.28522, 667.97742), ('white-queen', 599.38397, 157.43428), ('white-pawn', 598.17853, 559.29633), ('black-knight', 247.24434, 894.37616), ('black-queen', 605.74274, 898.34021), ('black-pawn', 493.16156, 567.02393), ('white-knight', 107.87492, 891.70898), ('white-rook', 473.46924, 455.97751), ('white-king', 372.60126, 258.17444), ('white-rook', 811.39362, 459.73904), ('black-knight', 936.54315, 568.60498), ('white-pawn', 724.6217, 248.65062), ('black-rook', 979.66339, 891.55054), ('white-pawn', 258.69957, 249.17889), ('black-rook', 951.5144, 785.72083), ('white-rook', 157.0375, 136.01924), ('white-queen', 370.83191, 256.64636), ('black-pawn', 840.48022, 782.94513), ('white-rook', 154.76483000000002, 247.49117), ('white-rook', 924.63684, 146.71678)}
# 2240.0955
# 2240.0955 80 28.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 1 black-queen, 2 black-rooks, 1 white-king, 3 white-knights, 3 white-pawns, 1 white-queen, 6 white-rooks, 12.4ms
# Speed: 5.1ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('black-knight', 936.11407, 569.66571), ('white-rook', 157.13671, 136.25043), ('white-pawn', 724.68958, 248.79732), ('black-rook', 951.05286, 786.22552), ('black-queen', 488.74097, 904.57971), ('white-knight', 703.00043, 370.15594), ('white-rook', 154.64337999999998, 248.13066), ('black-pawn', 492.92938, 567.82983), ('black-pawn', 711.11279, 793.0885), ('white-knight', 105.7504, 892.95178), ('black-knight', 246.84901, 894.71844), ('white-pawn', 597.87616, 560.21967), ('white-rook', 114.42722, 894.06049), ('white-knight', 116.21389, 894.05145), ('black-pawn', 599.1076, 668.5567), ('black-rook', 979.43164, 891.99725), ('white-king', 372.61639, 258.45505), ('black-pawn', 840.05328, 783.86438), ('white-pawn', 258.20052, 249.04234), ('white-rook', 810.37018, 460.93307), ('white-rook', 924.58405, 147.29523), ('white-queen', 599.38507, 157.72218), ('white-rook', 473.30853, 456.24252)}
# 3365.4688
# 3365.4688 80 42.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 2 black-rooks, 1 white-king, 2 white-knights, 3 white-pawns, 1 white-queen, 6 white-rooks, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 416)
# {('white-rook', 117.02043, 893.78241), ('white-rook', 156.99022, 136.12552), ('white-rook', 925.09192, 146.96489), ('black-knight', 247.47234, 894.45813), ('black-rook', 979.57068, 891.76428), ('black-knight', 936.76941, 569.04297), ('white-rook', 154.71615, 247.91095), ('black-pawn', 711.3125, 792.50262), ('black-pawn', 839.95337, 783.40613), ('white-pawn', 724.54681, 248.69286), ('black-pawn', 599.37866, 668.44476), ('white-rook', 473.19901, 456.20352), ('white-knight', 105.53832, 892.50604), ('white-pawn', 598.19379, 559.93341), ('white-queen', 599.53003, 157.51218), ('black-rook', 951.28357, 786.18518), ('white-pawn', 258.76212, 249.0007), ('white-knight', 703.31366, 369.69312), ('white-rook', 810.92963, 460.27994), ('black-pawn', 493.22537, 567.38013), ('white-king', 372.7879, 258.31625)}
# -358.5551
# -358.5551 80 -5.0
#
# 0: 384x416 2 black-knights, 3 black-pawns, 1 black-queen, 2 black-rooks, 1 white-king, 2 white-knights, 3 white-pawns, 1 white-queen, 6 white-rooks, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-rook', 113.8474, 894.14038), ('black-pawn', 493.30853, 568.38947), ('white-rook', 154.92147, 248.37778), ('black-queen', 488.75858, 905.23315), ('white-knight', 104.45607, 892.80139), ('white-rook', 473.84637, 456.45911), ('white-rook', 924.70331, 147.67285), ('black-pawn', 599.07819, 669.13605), ('white-pawn', 724.53827, 249.34503), ('white-rook', 157.4091, 136.36665), ('black-knight', 936.01257, 569.96765), ('black-rook', 950.95099, 786.26862), ('white-knight', 703.3493, 370.70041), ('black-pawn', 839.80536, 784.15222), ('white-king', 372.29092, 259.04947), ('black-rook', 979.54889, 892.82928), ('white-queen', 599.06604, 158.52718), ('white-rook', 811.45227, 462.65692), ('black-knight', 246.45877, 895.81903), ('white-pawn', 258.18071, 249.45297), ('white-pawn', 598.25531, 560.5437)}
# -421.35483
# -421.35483 80 -6.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 2 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('black-knight', 247.08368, 895.07623), ('white-rook', 154.81598, 248.60785), ('white-rook', 924.82867, 147.71155), ('white-rook', 474.30725, 456.29309), ('black-pawn', 493.19427, 567.94946), ('black-pawn', 711.62836, 792.93616), ('black-knight', 936.63837, 569.16333), ('white-queen', 599.30505, 157.98416), ('white-pawn', 598.55493, 560.17059), ('white-king', 372.40448, 258.92285), ('white-rook', 158.11606999999998, 136.43359), ('white-rook', 114.96812, 894.11517), ('white-knight', 106.37196, 892.99011), ('white-knight', 703.87079, 370.30161), ('black-rook', 979.83313, 891.91028), ('black-pawn', 599.56482, 668.73218), ('white-pawn', 725.37885, 249.01758), ('white-pawn', 258.91422, 249.27415), ('black-rook', 950.47449, 786.22443), ('white-rook', 811.18402, 460.85559), ('white-pawn', 474.65472, 455.54404), ('black-pawn', 840.23956, 783.83038), ('white-queen', 370.51819, 257.62085)}
# -1478.8083
# -1478.8083 80 -19.0
#
# 0: 384x416 2 black-knights, 3 black-pawns, 1 black-queen, 2 black-rooks, 1 white-king, 3 white-knights, 4 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 3.8ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 599.16858, 668.77112), ('white-rook', 114.82553, 893.72888), ('black-pawn', 492.75049, 567.90381), ('black-knight', 936.40686, 568.91504), ('white-knight', 106.10518, 892.44604), ('white-queen', 599.13348, 157.70728), ('white-rook', 473.48062, 456.20633), ('white-pawn', 473.72156, 455.5195), ('black-rook', 950.97473, 786.1734), ('white-knight', 702.9278, 369.93066), ('black-pawn', 839.85907, 783.87262), ('white-knight', 116.57246, 893.79541), ('white-rook', 156.81812, 136.26463), ('white-pawn', 724.23529, 248.81657), ('white-rook', 924.63544, 147.07169), ('white-king', 371.88458, 258.53677), ('white-rook', 154.53275, 248.04236), ('white-queen', 370.02307, 257.15009), ('black-rook', 979.45673, 891.71234), ('white-pawn', 258.03073, 249.24094), ('black-queen', 489.54416, 904.54541), ('white-rook', 811.37781, 462.39557), ('white-pawn', 597.93927, 560.21722), ('black-knight', 247.03702, 894.72015)}
# -330.5066
# -330.5066 80 -5.0
#
# 0: 384x416 2 black-knights, 3 black-pawns, 1 black-queen, 2 black-rooks, 1 white-king, 2 white-knights, 3 white-pawns, 2 white-queens, 4 white-rooks, 12.5ms
# Speed: 6.8ms preprocess, 12.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 416)
# {('white-pawn', 258.47186, 249.16522), ('black-knight', 936.58276, 568.96295), ('white-rook', 473.52652, 456.01254), ('white-rook', 157.65219000000002, 136.14925), ('white-rook', 924.91284, 147.1631), ('black-pawn', 599.32245, 668.54688), ('white-rook', 154.81089, 248.25642), ('black-rook', 979.78491, 891.84845), ('white-pawn', 724.4245, 248.90741), ('white-knight', 704.08221, 370.09888), ('white-queen', 370.50812, 257.21869), ('black-knight', 247.20677, 894.82477), ('white-queen', 599.37305, 157.57732), ('black-queen', 605.73737, 898.99371), ('black-pawn', 839.93402, 783.47473), ('white-pawn', 473.7908, 455.29398), ('white-king', 372.34296, 258.53818), ('black-rook', 951.45032, 786.16547), ('white-knight', 106.6301, 892.4306), ('black-pawn', 492.94781, 567.81171)}
# -362.934
# -362.934 80 -5.0
#
# 0: 384x416 2 black-knights, 3 black-pawns, 1 black-queen, 2 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 2 white-queens, 5 white-rooks, 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-rook', 473.16089, 455.75851), ('white-rook', 155.03201, 247.56015), ('white-pawn', 597.87463, 559.76727), ('white-queen', 598.84723, 157.1181), ('black-pawn', 599.06909, 668.22638), ('white-rook', 157.83067, 135.74004), ('white-knight', 702.7995, 369.81729), ('black-rook', 951.48145, 785.7511), ('white-queen', 371.03839, 256.64993), ('white-pawn', 724.34875, 248.70827), ('black-knight', 247.45978, 894.4931), ('black-pawn', 840.22223, 782.95892), ('white-knight', 108.21819, 892.3609), ('white-pawn', 258.48152, 248.81888), ('black-pawn', 492.71082, 567.23999), ('white-rook', 924.8175, 146.72777), ('black-queen', 604.48212, 898.52789), ('black-rook', 979.10797, 891.85449), ('white-king', 372.63727, 258.01721), ('white-pawn', 473.4122, 455.1384), ('white-rook', 811.32928, 459.66574), ('black-knight', 936.56915, 568.60663)}
# -1055.0121
# -1055.0121 80 -14.0
#
# 0: 384x416 2 black-knights, 3 black-pawns, 2 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 2 white-queens, 4 white-rooks, 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 493.10333, 567.51093), ('white-pawn', 724.54303, 248.74048), ('white-queen', 599.40173, 157.51419), ('white-knight', 107.28895, 892.71014), ('white-rook', 154.77283, 247.98271), ('black-rook', 951.31824, 786.17609), ('white-rook', 923.83661, 146.97198), ('black-knight', 247.52281, 894.81738), ('white-king', 372.43033, 258.46725), ('white-knight', 703.47723, 370.04071), ('white-rook', 158.00892, 136.08223), ('white-pawn', 598.21948, 560.03064), ('white-rook', 116.78662, 893.83838), ('white-pawn', 473.99417, 455.86743), ('black-pawn', 599.40826, 668.58618), ('black-knight', 936.54773, 569.02075), ('black-rook', 979.75702, 891.78314), ('white-queen', 370.59717, 256.79123), ('black-pawn', 840.20532, 783.69922), ('white-pawn', 258.4113, 248.98953)}
# 1668.9792
# 1668.9792 80 20.0
#
# 0: 384x416 2 black-knights, 3 black-pawns, 1 black-queen, 2 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 5 white-rooks, 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 599.1181, 668.08093), ('black-rook', 951.32703, 785.70734), ('black-queen', 605.54608, 898.33521), ('white-rook', 473.1261, 455.88235), ('white-queen', 599.49164, 156.9939), ('black-rook', 979.22302, 891.68262), ('white-pawn', 597.78992, 559.76154), ('black-knight', 247.1031, 894.47723), ('white-rook', 156.82138, 135.53755), ('white-knight', 107.68429, 891.52124), ('white-pawn', 473.4827, 455.23285), ('white-rook', 923.94946, 146.46945), ('white-rook', 811.29858, 459.68842), ('white-pawn', 258.10677999999996, 248.31163), ('white-knight', 702.32043, 370.01135), ('white-king', 372.83563, 257.62955), ('white-rook', 155.12727999999998, 246.94238), ('black-pawn', 492.578, 567.41357), ('black-knight', 936.86859, 568.63989), ('black-pawn', 839.37866, 782.81067), ('white-pawn', 724.28271, 248.37428)}
# -326.27185
# -326.27185 80 -5.0
#
# 0: 384x416 2 black-knights, 3 black-pawns, 1 black-queen, 2 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 7 white-rooks, 12.4ms
# Speed: 3.6ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('black-rook', 951.70978, 785.85138), ('white-rook', 473.25763, 456.06451), ('black-pawn', 839.79651, 783.17981), ('white-pawn', 598.08917, 559.96649), ('white-rook', 155.10627, 247.43622), ('black-queen', 605.76862, 898.31354), ('black-knight', 936.8537, 568.73694), ('black-pawn', 492.85229, 567.33521), ('white-rook', 703.09027, 369.7063), ('white-pawn', 724.48297, 248.40672), ('black-knight', 247.46645, 894.68787), ('white-rook', 114.64212, 892.69226), ('black-rook', 979.85034, 891.61713), ('white-king', 372.98822, 257.94781), ('white-queen', 599.33734, 157.36887), ('white-pawn', 258.51464999999996, 248.58859), ('white-knight', 112.21009, 893.15637), ('white-knight', 703.50531, 369.73315), ('white-rook', 924.84363, 146.63191), ('white-pawn', 473.60065, 455.33981), ('white-rook', 156.89766, 135.92372), ('white-rook', 811.36188, 459.65259), ('black-pawn', 599.35089, 668.1748)}
# 3085.5793
# 3085.5793 80 38.0
#
# 0: 384x416 2 black-knights, 3 black-pawns, 1 black-queen, 2 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 6 white-rooks, 12.4ms
# Speed: 3.6ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-rook', 473.31934, 455.62811), ('white-pawn', 258.25391, 248.54652), ('black-knight', 247.08246, 894.27679), ('white-pawn', 473.61548, 454.91061), ('white-queen', 599.55914, 157.44214), ('white-rook', 811.46936, 459.45016), ('black-queen', 605.73236, 897.90942), ('white-rook', 156.99755, 135.40892), ('white-king', 372.75641, 257.70908), ('black-rook', 951.61298, 785.10632), ('white-rook', 703.01562, 369.65781), ('black-pawn', 711.85571, 791.138), ('white-pawn', 597.97974, 559.28094), ('white-pawn', 724.49927, 248.47118), ('white-knight', 703.3985, 369.73065), ('white-rook', 155.34768, 247.39244), ('black-knight', 936.45514, 568.57007), ('black-rook', 979.20038, 889.79266), ('white-knight', 108.47513, 891.07556), ('black-pawn', 492.82489, 566.73663), ('black-pawn', 599.32446, 668.00116), ('white-rook', 925.20544, 146.15468)}
# 893.6122
# 893.6122 80 11.0
#
# 0: 384x416 2 black-knights, 3 black-pawns, 3 black-queens, 2 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 416)
# {('white-queen', 370.40875, 256.22083), ('white-pawn', 597.75189, 559.62201), ('white-pawn', 473.68433, 454.89841), ('white-king', 373.10495, 257.82098), ('black-rook', 951.36072, 785.37653), ('black-pawn', 492.87982, 566.77277), ('white-queen', 599.46771, 157.49667), ('black-pawn', 599.14563, 667.8468), ('black-queen', 370.53922, 896.30774), ('black-knight', 247.4458, 894.38495), ('white-pawn', 258.58466, 248.45355), ('black-rook', 977.24432, 884.26221), ('white-pawn', 724.54443, 248.44725), ('white-rook', 155.40086, 247.32764), ('white-rook', 114.44423, 892.91119), ('white-rook', 811.44324, 459.52621), ('white-rook', 925.03534, 146.00629), ('black-queen', 490.00305, 903.70465), ('white-knight', 703.14313, 369.67267), ('black-pawn', 840.3858, 782.27789), ('black-knight', 936.55432, 568.40973), ('white-rook', 473.41592, 455.5752), ('white-knight', 107.63041, 891.69885), ('black-queen', 605.56848, 897.57269), ('white-rook', 156.91992, 135.70561)}
# 293.58435
# 293.58435 80 3.0
#
# 0: 384x416 2 black-knights, 2 black-pawns, 1 black-queen, 1 black-rook, 1 white-king, 2 white-knights, 2 white-pawns, 2 white-queens, 5 white-rooks, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 416)
# {('white-rook', 811.48743, 459.56061), ('black-pawn', 493.14459, 566.73816), ('white-rook', 155.21929, 247.28944), ('black-knight', 936.40576, 568.79755), ('white-pawn', 724.66772, 248.46135), ('white-king', 372.88501, 257.72269), ('black-pawn', 599.02563, 668.06689), ('white-rook', 157.18864000000002, 135.37064), ('white-rook', 473.4263, 455.26779), ('black-knight', 246.98271, 894.32196), ('white-queen', 371.02216, 256.29385), ('black-rook', 949.44611, 786.61072), ('white-knight', 108.81216, 891.26318), ('white-queen', 599.45856, 157.46817), ('white-rook', 925.33624, 146.06972), ('white-knight', 703.64075, 369.68649), ('white-pawn', 258.95135, 249.06412), ('black-queen', 607.30951, 897.82147)}
# 2314.3777
# 2314.3777 80 28.0
#
# 0: 384x416 2 black-knights, 2 black-pawns, 1 black-queen, 1 white-king, 2 white-knights, 3 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 598.94952, 668.21533), ('black-queen', 603.65765, 897.34351), ('white-rook', 923.98956, 146.04398), ('white-queen', 598.52808, 157.32822), ('white-rook', 473.26273, 455.85672), ('black-knight', 246.9389, 894.52814), ('white-rook', 157.07143000000002, 135.44272), ('white-knight', 703.13147, 369.53384), ('white-pawn', 597.51715, 559.9787), ('white-knight', 107.53639, 892.05371), ('white-rook', 155.3313, 247.34344), ('white-rook', 811.03473, 459.89011), ('white-queen', 370.33875, 256.27945), ('white-rook', 114.95858, 892.29224), ('black-pawn', 492.62921, 567.25751), ('white-pawn', 258.91216, 248.99564), ('black-knight', 936.82281, 568.70782), ('white-pawn', 724.66803, 248.38974), ('white-king', 372.93399, 257.85165)}
# 997.2459
# 997.2459 80 12.0
#
# 0: 384x416 2 black-knights, 3 black-pawns, 1 black-rook, 2 white-knights, 1 white-pawn, 2 white-queens, 4 white-rooks, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 491.685, 567.32166), ('black-knight', 941.24677, 541.24237), ('white-knight', 703.23694, 369.58044), ('white-rook', 157.87842999999998, 246.0448), ('black-pawn', 598.27203, 667.20288), ('white-knight', 110.93205, 891.14014), ('white-rook', 159.84172999999998, 136.43089), ('black-rook', 974.76978, 891.7475), ('white-rook', 924.91522, 148.03043), ('white-pawn', 725.2038, 249.78893), ('black-knight', 247.22884, 894.24243), ('black-pawn', 710.88776, 790.76611), ('white-queen', 372.09177, 247.86606), ('white-queen', 600.28802, 159.05499), ('white-rook', 115.78239, 892.48529)}
# -289.79645
# -289.79645 80 -4.0
#
# 0: 384x416 2 black-knights, 2 black-pawns, 1 white-king, 1 white-knight, 1 white-pawn, 2 white-queens, 4 white-rooks, 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-rook', 925.45416, 146.92001), ('white-king', 371.82367, 258.87393), ('white-rook', 157.97417000000002, 135.25681), ('white-knight', 110.2404, 890.3009), ('black-pawn', 597.77466, 666.68628), ('white-queen', 600.32642, 158.71567), ('white-queen', 370.53619, 256.97394), ('black-pawn', 491.40802, 566.09113), ('white-rook', 115.28093, 891.85193), ('black-knight', 935.80701, 555.69653), ('white-pawn', 723.93945, 249.64664), ('black-knight', 246.75711, 893.53204), ('white-rook', 809.78754, 458.58594)}
# 3699.8174
# 3699.8174 80 46.0
#
# 0: 384x416 2 black-knights, 3 black-pawns, 1 white-king, 1 white-knight, 1 white-pawn, 2 white-queens, 4 white-rooks, 12.4ms
# Speed: 3.6ms preprocess, 12.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 489.24905, 567.53687), ('white-queen', 600.00726, 159.42757), ('white-rook', 924.85248, 148.24544), ('white-rook', 811.23486, 459.69208), ('white-rook', 114.72294, 893.09875), ('black-knight', 247.41327, 894.34351), ('white-knight', 109.99277, 891.97949), ('black-pawn', 596.49481, 667.18756), ('white-rook', 159.29671000000002, 136.60368), ('white-queen', 370.98932, 261.54797), ('white-king', 370.88562, 261.70737), ('white-pawn', 725.35535, 249.86536), ('black-knight', 935.17725, 566.52423), ('black-pawn', 709.14874, 792.86407)}
# 988.45123
# 988.45123 80 12.0
#
# 0: 384x416 1 black-king, 2 black-knights, 2 black-pawns, 1 white-bishop, 1 white-king, 1 white-knight, 1 white-pawn, 1 white-queen, 4 white-rooks, 12.4ms
# Speed: 3.6ms preprocess, 12.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 416)
# {('white-pawn', 724.57196, 249.72844), ('white-queen', 599.93793, 158.85014), ('white-rook', 925.93079, 147.52115), ('black-king', 133.65716, 440.34348), ('white-king', 373.05701, 261.03531), ('white-bishop', 378.06772, 144.83287), ('white-rook', 114.06362, 891.61182), ('black-knight', 247.134, 894.29059), ('white-rook', 810.65997, 460.38654), ('black-pawn', 595.88483, 665.97443), ('black-pawn', 710.16968, 790.79834), ('white-rook', 158.69952999999998, 136.64961), ('white-knight', 106.19962, 890.27765), ('black-knight', 936.88977, 569.15076)}
# -218.16278
# -218.16278 80 -3.0
#
# 0: 384x416 1 black-knight, 3 black-pawns, 1 black-rook, 1 white-king, 1 white-knight, 1 white-pawn, 2 white-queens, 5 white-rooks, 12.4ms
# Speed: 4.2ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 710.93347, 791.07129), ('black-knight', 246.94073, 893.93121), ('white-rook', 471.95834, 455.25565), ('white-pawn', 257.73299, 250.34909), ('black-pawn', 599.27283, 667.19012), ('black-pawn', 491.90659, 566.74451), ('white-queen', 598.55707, 158.55475), ('white-queen', 370.2153, 257.22943), ('white-king', 372.31219, 258.45996), ('black-rook', 123.63764, 462.63336), ('white-rook', 115.94235, 892.53284), ('white-rook', 924.56311, 147.5231), ('white-rook', 153.88869, 247.01537), ('white-knight', 109.25551, 891.01337), ('white-rook', 157.13531, 136.50618)}
# 293.1829
# 293.1829 80 3.0
#
# 0: 384x416 1 black-king, 2 black-knights, 3 black-pawns, 2 black-rooks, 1 white-king, 2 white-knights, 2 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 3.6ms preprocess, 12.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 492.22546, 566.3808), ('white-knight', 703.18512, 371.03134), ('black-pawn', 599.16681, 667.31213), ('white-rook', 472.45724, 454.79178), ('white-knight', 108.69241, 890.55701), ('white-king', 371.89941, 257.84174), ('black-rook', 123.33523, 461.29944), ('white-queen', 370.01706, 256.99976), ('black-rook', 975.38123, 890.31458), ('black-pawn', 708.74121, 792.48755), ('white-rook', 115.69484, 892.0849), ('white-rook', 924.63184, 145.86174), ('white-rook', 154.02366999999998, 246.28535), ('white-queen', 599.09528, 157.8696), ('black-knight', 246.96136, 893.62842), ('white-rook', 157.49355, 135.88722), ('white-pawn', 724.54663, 248.93079), ('white-pawn', 257.80350999999996, 249.58086), ('white-rook', 810.48071, 459.54398), ('black-knight', 937.14642, 568.39911), ('black-king', 122.72157, 460.75003)}
# -938.08246
# -938.08246 80 -12.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 2 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 3.8ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-king', 371.98856, 258.12585), ('white-rook', 472.7901, 455.33078), ('white-pawn', 724.8009, 248.74951), ('black-knight', 936.85284, 568.47852), ('black-knight', 247.97627, 893.86926), ('black-pawn', 599.3092, 667.75867), ('black-pawn', 839.71423, 781.82892), ('black-pawn', 712.02502, 790.45673), ('black-rook', 951.36993, 784.89185), ('white-queen', 370.07758, 257.23669), ('white-pawn', 258.20918, 249.87856), ('white-rook', 811.62897, 459.44089), ('white-rook', 158.12279, 136.79337), ('white-knight', 704.0722, 371.08966), ('white-rook', 924.79279, 145.92397), ('white-queen', 599.1344, 158.15807), ('white-rook', 115.79066, 892.34076), ('black-rook', 979.63422, 889.30109), ('white-rook', 154.98453999999998, 246.89081), ('black-rook', 123.49208, 462.62827), ('black-pawn', 492.48755, 566.57892), ('white-knight', 110.6767, 890.92792)}
# -1641.3629
# -1641.3629 80 -21.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 2 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 416)
# {('black-rook', 950.97571, 784.9754), ('white-king', 371.98474, 257.53961), ('white-pawn', 257.86058, 249.44225), ('black-pawn', 492.15369, 566.37427), ('white-knight', 107.30826, 890.37164), ('black-knight', 247.18466, 894.15454), ('white-knight', 704.03528, 370.99423), ('black-pawn', 599.02271, 668.2229), ('white-rook', 811.86609, 459.12253), ('black-pawn', 711.24805, 791.54346), ('white-pawn', 724.65741, 248.71509), ('black-pawn', 839.94751, 781.24951), ('white-rook', 114.20333, 891.63531), ('white-rook', 157.78981, 135.98438), ('white-rook', 924.71942, 146.35941), ('black-knight', 934.88055, 568.31909), ('black-rook', 978.63721, 891.21747), ('white-queen', 599.17627, 158.03078), ('white-queen', 370.07919, 256.61887), ('white-rook', 154.91018, 246.10086), ('black-rook', 123.77378, 461.9418), ('white-rook', 472.72916, 455.04974)}
# 1657.6913
# 1657.6913 80 20.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 2 white-pawns, 2 white-queens, 7 white-rooks, 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('black-knight', 936.08838, 568.48468), ('black-pawn', 839.45312, 782.00342), ('white-knight', 107.97935, 890.7453), ('black-rook', 951.21954, 784.94836), ('white-knight', 703.66998, 370.965), ('white-pawn', 258.23589000000004, 249.92984), ('white-pawn', 724.65039, 248.88522), ('white-queen', 370.3082, 256.62723), ('black-pawn', 492.2468, 566.61206), ('black-knight', 246.55817, 894.48804), ('white-rook', 157.48627, 136.04572), ('white-queen', 598.95569, 157.97333), ('black-pawn', 711.56726, 791.16382), ('white-rook', 154.89909, 246.43901), ('white-rook', 473.12531, 455.94318), ('black-pawn', 599.23621, 667.98334), ('white-rook', 702.39508, 370.57932), ('white-king', 372.17029, 257.65659), ('white-rook', 115.00584, 891.88641), ('black-rook', 978.78503, 891.25751), ('black-rook', 123.45917, 462.36182), ('white-rook', 924.75635, 146.17336), ('white-rook', 811.78619, 459.14395)}
# 1623.904
# 1623.904 80 20.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 2 white-pawns, 2 white-queens, 8 white-rooks, 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 416)
# {('white-pawn', 724.85907, 248.83841), ('white-king', 372.24109, 257.69833), ('white-rook', 157.43878999999998, 136.05751), ('white-rook', 154.69339, 246.67107), ('white-queen', 370.28339, 256.73984), ('black-pawn', 711.58691, 791.13849), ('white-knight', 109.69061, 891.20227), ('white-pawn', 258.53013999999996, 249.87868), ('black-rook', 978.93164, 891.19971), ('white-rook', 702.58997, 370.66318), ('white-rook', 473.0401, 455.58865), ('black-knight', 936.00909, 568.58783), ('black-pawn', 600.47815, 668.13519), ('white-rook', 811.62433, 459.17123), ('black-rook', 123.42565, 462.57001), ('white-knight', 703.88983, 371.02917), ('black-pawn', 839.43488, 781.96405), ('white-queen', 599.12122, 157.75371), ('white-rook', 114.15704, 891.69586), ('black-knight', 247.22989, 894.42023), ('black-rook', 951.29498, 785.01727), ('black-pawn', 492.54935, 566.604), ('white-rook', 599.08832, 558.21112), ('white-rook', 924.84265, 145.99597)}
# 449.99564
# 449.99564 80 5.0
#
# 0: 384x416 1 black-king, 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 2 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 3.6ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('black-rook', 952.17139, 785.23627), ('white-pawn', 257.89432999999997, 250.04747), ('white-queen', 369.46841, 256.84909), ('white-rook', 157.35513, 136.05341), ('white-king', 372.33997, 257.97559), ('black-pawn', 492.12653, 566.8877), ('white-pawn', 724.53363, 248.8054), ('white-rook', 472.61096, 456.22406), ('black-knight', 936.88239, 568.65765), ('white-rook', 154.36520000000002, 246.96417), ('black-rook', 123.22285, 462.80878), ('white-rook', 115.88362, 892.72247), ('black-rook', 978.93622, 891.29608), ('white-queen', 598.68567, 157.89662), ('white-knight', 109.92548, 891.35077), ('white-rook', 924.70544, 146.22279), ('black-pawn', 600.15417, 668.13934), ('black-pawn', 711.43286, 791.29486), ('black-pawn', 839.4588, 782.05261), ('white-knight', 703.57074, 371.03452), ('white-rook', 811.34119, 459.67581), ('black-king', 122.84541, 462.81839), ('black-knight', 247.1142, 894.36737)}
# 2422.1807
# 2422.1807 80 30.0
#
# 0: 384x416 1 black-king, 2 black-knights, 4 black-pawns, 2 black-rooks, 1 white-king, 2 white-knights, 2 white-pawns, 2 white-queens, 7 white-rooks, 12.4ms
# Speed: 3.8ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('black-rook', 951.73962, 784.53992), ('white-rook', 473.02707, 456.09018), ('white-pawn', 258.4995, 250.15076), ('white-rook', 702.99915, 370.64639), ('white-rook', 924.94171, 146.19949), ('white-rook', 115.84683, 892.65405), ('white-pawn', 724.63129, 248.73827), ('white-rook', 811.76776, 459.54733), ('black-pawn', 839.89081, 782.01019), ('white-rook', 155.05122, 246.86296), ('black-rook', 979.08582, 891.24597), ('black-pawn', 711.58307, 791.22052), ('black-king', 123.34103, 462.7413), ('black-pawn', 600.49841, 668.29254), ('black-knight', 936.9516, 568.67444), ('black-knight', 247.51224, 894.44189), ('white-knight', 110.71669, 891.36804), ('white-king', 372.12183, 257.93924), ('white-rook', 157.7483, 135.84271), ('white-queen', 370.21954, 257.20847), ('white-queen', 598.72729, 157.94673), ('white-knight', 703.32336, 371.00861), ('black-pawn', 492.44495, 566.94147)}
# 1662.1271
# 1662.1271 80 20.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 2 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-rook', 154.88608, 246.83238), ('white-pawn', 257.71918, 249.82153), ('black-rook', 978.98853, 891.31464), ('black-knight', 247.15005, 894.43225), ('white-queen', 369.67282, 256.46841), ('white-rook', 472.53592, 456.10736), ('black-pawn', 491.89423, 567.00427), ('white-pawn', 724.73016, 248.69678), ('white-rook', 114.05082, 891.84161), ('white-knight', 703.60553, 370.7005), ('white-rook', 924.75421, 146.09944), ('white-king', 372.53049, 257.83499), ('white-rook', 157.43632, 135.90538), ('white-queen', 598.5741, 157.67941), ('white-knight', 109.64024, 891.474), ('black-pawn', 598.87811, 668.19794), ('black-pawn', 839.55615, 781.76764), ('black-pawn', 711.61603, 790.92346), ('black-knight', 936.07782, 568.63574), ('black-rook', 952.18231, 785.28479), ('white-rook', 811.35559, 459.4577), ('black-rook', 122.805, 462.70502)}
# -1604.6005
# -1604.6005 80 -21.0
#
# 0: 384x416 1 black-king, 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 2 white-pawns, 2 white-queens, 7 white-rooks, 12.4ms
# Speed: 3.6ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-pawn', 725.0965, 248.66263), ('white-queen', 599.09546, 157.94835), ('black-rook', 123.69745, 462.48151), ('black-king', 123.40342, 462.59616), ('black-knight', 936.40143, 568.44916), ('white-knight', 703.79163, 370.62335), ('black-pawn', 599.44708, 667.90326), ('white-rook', 473.1601, 455.68073), ('black-knight', 247.39478, 894.32751), ('white-rook', 116.03667, 892.61096), ('black-pawn', 492.64682, 566.76385), ('white-rook', 157.07289, 135.40601), ('black-pawn', 840.26996, 781.8103), ('white-rook', 812.27625, 458.93082), ('white-rook', 155.26952, 246.58405), ('white-rook', 925.26263, 146.15138), ('white-rook', 599.3067, 558.1828), ('white-king', 372.91949, 257.89429), ('white-pawn', 258.62296000000003, 249.87526), ('black-pawn', 711.88068, 790.81989), ('white-knight', 110.12422, 891.33142), ('white-queen', 369.76852, 256.5975), ('black-rook', 979.40808, 891.2807), ('black-rook', 951.79932, 785.29712)}
# 468.93314
# 468.93314 80 5.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 2 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 3.5ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-king', 371.73199, 257.65863), ('white-rook', 925.00018, 146.06316), ('black-knight', 936.53088, 568.33368), ('black-knight', 246.77777, 894.50696), ('black-rook', 122.91348, 462.48621), ('white-queen', 598.87616, 157.36884), ('black-pawn', 598.96259, 668.09082), ('white-rook', 156.92074, 135.62547), ('white-rook', 472.67157, 455.73004), ('black-rook', 951.37738, 785.33185), ('black-rook', 978.87708, 891.52356), ('white-pawn', 725.05243, 248.5899), ('white-rook', 116.10066, 892.70892), ('white-knight', 110.1624, 891.37341), ('white-queen', 369.75394, 256.2814), ('white-pawn', 257.80032, 249.5632), ('black-pawn', 491.91785, 566.91351), ('white-rook', 811.74731, 459.08246), ('black-pawn', 839.43616, 781.79919), ('white-knight', 703.80957, 370.23209), ('white-rook', 154.89986, 246.63316), ('black-pawn', 711.54175, 790.88251)}
# -352.62097
# -352.62097 80 -5.0
#
# 0: 384x416 1 black-king, 2 black-knights, 5 black-pawns, 2 black-rooks, 1 white-king, 2 white-knights, 3 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 493.48752, 566.45581), ('white-king', 372.78949, 257.77756), ('white-pawn', 598.32605, 558.40436), ('black-pawn', 600.42291, 668.18451), ('black-knight', 936.85547, 568.33459), ('black-pawn', 711.63348, 791.0578), ('white-pawn', 725.30145, 248.67206), ('white-knight', 107.41875, 890.25055), ('black-pawn', 839.54156, 781.64819), ('white-rook', 812.15344, 459.22009), ('black-king', 124.05304, 462.07507), ('white-rook', 154.94733, 246.46606), ('black-rook', 951.94965, 785.19604), ('white-queen', 371.24893, 256.77432), ('white-rook', 158.48247, 135.07965), ('white-rook', 473.02133, 454.88852), ('white-queen', 600.09503, 157.4023), ('white-pawn', 258.94417999999996, 249.84607), ('black-pawn', 589.36438, 778.83209), ('white-rook', 924.92908, 146.35674), ('white-knight', 704.78003, 370.92496), ('black-rook', 979.32184, 890.95428), ('black-knight', 246.7215, 894.56549), ('white-rook', 115.92539, 892.2384)}
# 0.0
# 0.0 80 0.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 3 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 840.05035, 781.91553), ('black-rook', 123.14807, 462.22256), ('white-king', 372.76053, 257.62634), ('black-rook', 978.43134, 891.28387), ('white-knight', 703.05994, 370.44379), ('white-rook', 157.00555, 135.17651), ('black-knight', 936.78461, 568.54645), ('white-rook', 924.76978, 146.35336), ('white-rook', 472.83929, 455.18405), ('white-pawn', 724.52008, 248.76619), ('white-rook', 113.49628, 891.45483), ('black-knight', 247.11848, 894.3761), ('white-pawn', 258.5038, 249.85606), ('white-rook', 155.13481000000002, 246.47375), ('black-rook', 952.21069, 785.27698), ('white-queen', 370.41473, 256.25674), ('white-rook', 811.97089, 459.15485), ('white-pawn', 597.73651, 558.78839), ('white-knight', 107.49012, 890.39746), ('black-pawn', 600.11719, 668.23285), ('white-queen', 598.93469, 157.31482), ('black-pawn', 711.6673, 791.05493), ('black-pawn', 492.51953, 566.59625)}
# 0.0
# 0.0 80 0.0
#
# 0: 384x416 1 black-knight, 6 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 3 white-pawns, 2 white-queens, 7 white-rooks, 12.4ms
# Speed: 3.8ms preprocess, 12.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 712.38184, 791.29358), ('white-rook', 473.4101, 454.24185), ('black-rook', 124.27569, 460.67654), ('white-knight', 704.94281, 370.8168), ('black-pawn', 493.47522, 566.22034), ('white-rook', 155.03225, 245.84088), ('black-pawn', 247.49611, 893.11261), ('white-rook', 157.47593, 135.08757), ('black-pawn', 590.34778, 778.70154), ('white-knight', 110.5794, 890.46277), ('white-rook', 925.11316, 146.11816), ('white-queen', 371.88846, 256.49234), ('black-rook', 978.94379, 890.48206), ('black-knight', 936.52942, 568.36914), ('white-pawn', 259.26351999999997, 249.29442), ('black-rook', 951.65057, 784.91083), ('white-king', 373.31894, 257.30746), ('white-queen', 600.41681, 157.50706), ('black-pawn', 839.87415, 781.29315), ('white-rook', 703.4859, 370.34903), ('black-pawn', 600.11591, 667.63171), ('white-pawn', 599.38342, 557.80701), ('white-pawn', 725.45221, 248.57191), ('white-rook', 812.56067, 459.18347), ('white-rook', 599.73474, 557.22235)}
# 1584.2533
# 1584.2533 80 19.0
#
# 0: 384x416 1 black-king, 2 black-knights, 4 black-pawns, 2 black-rooks, 1 white-king, 2 white-knights, 3 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 3.4ms preprocess, 12.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 416)
# {('black-king', 123.98599, 462.09656), ('white-queen', 600.27759, 158.27089), ('white-knight', 109.73355, 891.13391), ('black-pawn', 493.29355, 566.69568), ('black-knight', 246.48064, 894.11707), ('white-pawn', 598.09515, 559.18134), ('white-rook', 157.85579, 135.00365), ('black-rook', 951.8418, 784.7547), ('white-king', 373.50372, 257.73611), ('white-queen', 372.14612, 256.87985), ('white-rook', 115.86807, 892.56708), ('black-knight', 935.97418, 568.81512), ('black-pawn', 600.4317, 668.16815), ('white-rook', 473.02951, 455.5603), ('white-rook', 925.48456, 146.7088), ('white-pawn', 725.71509, 248.87872), ('white-rook', 155.50110999999998, 246.61482), ('black-rook', 978.94714, 891.18848), ('white-pawn', 259.10431, 249.84689), ('white-knight', 704.88409, 370.93472), ('black-pawn', 839.85626, 782.12738), ('white-rook', 811.83398, 459.73871), ('black-pawn', 711.86011, 791.12598)}
# 0.0
# 0.0 80 0.0
#
# 0: 384x416 1 black-king, 2 black-knights, 4 black-pawns, 1 black-rook, 1 white-king, 2 white-knights, 3 white-pawns, 1 white-queen, 6 white-rooks, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 711.99011, 791.2489), ('white-king', 373.4613, 257.9704), ('white-rook', 116.1499, 892.34711), ('white-rook', 925.66895, 147.13438), ('black-pawn', 600.56036, 668.22809), ('black-pawn', 840.37909, 782.19342), ('white-rook', 473.34995, 455.90146), ('black-rook', 979.64215, 891.15808), ('white-rook', 812.08679, 459.61575), ('white-knight', 111.11042, 890.95874), ('white-rook', 155.40512, 246.6422), ('white-pawn', 259.44597999999996, 249.88115), ('black-knight', 936.3266, 568.6861), ('white-pawn', 598.50092, 559.04065), ('black-pawn', 493.58859, 566.59869), ('white-pawn', 725.8598, 248.81487), ('white-rook', 157.82118, 135.01767), ('white-queen', 600.39111, 158.2504), ('black-knight', 246.98206, 894.2605), ('white-knight', 705.26892, 370.88855), ('black-king', 123.90799, 462.28738)}
# 0.0
# 0.0 80 0.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 2 black-rooks, 1 white-king, 2 white-knights, 2 white-pawns, 2 white-queens, 7 white-rooks, 12.4ms
# Speed: 3.6ms preprocess, 12.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 416)
# ...
# {('white-rook', 473.16458, 453.44113), ('black-rook', 951.41473, 785.57477), ('white-knight', 108.7826, 892.28009), ('black-knight', 936.3606, 568.06238), ('white-rook', 155.53812, 133.12204), ('white-rook', 703.37231, 369.09314), ('black-pawn', 711.44397, 791.69824), ('black-rook', 978.65399, 891.47369), ('white-rook', 812.16602, 458.93375), ('white-rook', 255.19707, 342.98288), ('white-pawn', 599.06653, 557.38135), ('white-pawn', 255.07545, 342.96063), ('black-pawn', 599.19757, 667.91443), ('white-knight', 703.89587, 369.22748), ('white-rook', 924.79211, 145.50359), ('black-pawn', 491.39499, 566.50714), ('white-rook', 116.48034, 893.5238), ('black-rook', 123.36936, 461.40393), ('white-king', 370.34802, 254.48711), ('white-rook', 151.99081, 243.42743), ('black-pawn', 840.51923, 782.49591), ('black-knight', 247.19199, 894.60132), ('black-king', 122.98286, 461.61404), ('white-pawn', 724.53589, 247.20618), ('white-queen', 599.6131, 155.44864)}
# -1054.315
# -1054.315 80 -14.0
#
# 0: 384x416 4 black-knights, 3 black-pawns, 1 black-queen, 2 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 2 white-queens, 6 white-rooks, 12.4ms
# Speed: 4.0ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('black-knight', 951.77991, 784.89435), ('black-queen', 368.50461, 897.1618), ('black-knight', 246.43269, 894.85217), ('white-king', 369.39633, 254.62627), ('white-queen', 368.64206, 255.00858999999997), ('white-rook', 702.36816, 368.8765), ('white-rook', 810.90283, 459.12628), ('black-knight', 487.84879, 904.26514), ('black-pawn', 839.63293, 782.38708), ('white-rook', 112.38126, 892.74091), ('white-rook', 155.09322, 133.4874), ('black-rook', 121.93703, 461.58063), ('white-pawn', 598.14136, 557.68292), ('black-knight', 936.11371, 568.05603), ('white-pawn', 254.19708, 342.83621), ('black-rook', 977.37012, 891.58972), ('black-pawn', 598.00745, 667.87036), ('white-knight', 104.82354, 892.61523), ('black-pawn', 490.51517, 566.48627), ('white-rook', 151.49969, 244.06668), ('white-pawn', 471.51926, 453.56058), ('white-rook', 924.58374, 145.4424), ('white-knight', 702.73071, 368.98584), ('white-queen', 599.19739, 155.32433), ('white-pawn', 723.88037, 247.20622)}
# 1661.5588
# 1661.5588 80 20.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 7 white-rooks, 12.4ms
# Speed: 3.6ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-pawn', 599.25012, 557.46851), ('white-rook', 156.02122, 133.58492), ('white-rook', 812.3515, 458.98264), ('white-pawn', 472.64557, 453.91519), ('white-queen', 599.76605, 155.46465), ('white-rook', 116.39055, 893.93042), ('black-pawn', 491.56137, 566.66779), ('black-rook', 951.33777, 785.56738), ('white-pawn', 724.6109, 247.1716), ('black-rook', 123.0863, 461.87076), ('white-pawn', 255.00572, 342.9892), ('white-rook', 255.13138, 343.0293), ('white-knight', 703.99078, 369.00342), ('white-rook', 924.91742, 145.38347), ('black-knight', 247.61732, 894.60626), ('white-rook', 151.67588, 243.80707), ('white-knight', 105.79966, 892.05548), ('white-king', 370.6098, 254.70325), ('black-pawn', 840.59528, 782.39264), ('black-pawn', 711.54224, 791.60468), ('black-rook', 978.37512, 891.57526), ('black-knight', 936.54407, 568.11108), ('black-pawn', 599.20416, 667.94684), ('white-rook', 703.4649, 368.87213)}
# -330.14365
# -330.14365 80 -5.0
#
# 0: 384x416 4 black-knights, 3 black-pawns, 2 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 6 white-rooks, 12.4ms
# Speed: 3.8ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-rook', 155.12146, 133.24451), ('white-pawn', 723.60699, 247.07118), ('black-pawn', 839.51154, 781.88904), ('white-pawn', 598.20654, 557.74762), ('black-knight', 951.53461, 784.72034), ('white-knight', 104.67316, 892.4574), ('white-rook', 702.46741, 368.65698), ('white-king', 369.84, 254.39809000000002), ('black-knight', 487.79221, 904.16974), ('black-pawn', 490.58887, 566.38068), ('black-rook', 977.28308, 891.5675), ('white-rook', 923.47931, 145.48703), ('black-rook', 121.80458, 461.28864), ('white-pawn', 471.42172, 453.46368), ('white-knight', 702.82227, 368.83121), ('black-knight', 246.68941, 894.50354), ('white-rook', 151.21317, 243.9817), ('white-pawn', 254.46306, 342.51697), ('black-pawn', 597.39789, 667.83551), ('white-rook', 810.83606, 459.10791), ('white-rook', 112.19806, 892.67352), ('white-queen', 598.49817, 155.01967), ('black-knight', 935.68713, 568.10931)}
# 0.0
# 0.0 80 0.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 3 white-pawns, 1 white-queen, 7 white-rooks, 12.4ms
# Speed: 4.6ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-rook', 812.21332, 458.86249), ('black-knight', 247.25371, 894.63434), ('white-pawn', 255.01741, 343.08401), ('white-rook', 156.00378, 134.02711), ('black-pawn', 599.33813, 667.802), ('white-knight', 704.17023, 368.69769), ('black-rook', 951.66034, 785.45239), ('white-queen', 599.70349, 155.24257), ('white-rook', 152.4521, 244.27441), ('black-pawn', 711.83258, 791.10004), ('black-rook', 978.92383, 891.46069), ('white-pawn', 599.33405, 557.33508), ('white-rook', 255.17111, 343.14951), ('white-pawn', 724.68817, 247.06137), ('black-pawn', 839.51538, 782.29395), ('black-rook', 123.5029, 461.83075), ('white-rook', 114.52032, 894.30609), ('white-knight', 107.77784, 893.24445), ('white-king', 370.48013, 254.23798), ('white-rook', 472.33618, 453.7916), ('black-pawn', 491.79346, 566.50494), ('black-knight', 936.34265, 568.03888), ('white-rook', 925.03467, 145.60922)}
# 1597.8113
# 1597.8113 80 19.0
#
# 0: 384x416 2 black-knights, 2 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 3 white-pawns, 1 white-queen, 7 white-rooks, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 491.01089, 566.5083), ('white-pawn', 598.2666, 557.72876), ('black-pawn', 598.00403, 667.86383), ('white-king', 369.67767, 254.2413), ('white-knight', 105.98029, 892.94861), ('white-rook', 923.88934, 145.44391), ('white-rook', 155.1911, 134.12967), ('black-rook', 951.24805, 785.49036), ('white-rook', 471.91849, 453.7493), ('white-rook', 113.69348, 893.97571), ('white-rook', 810.93372, 458.91083), ('white-pawn', 254.66174, 342.74689), ('white-rook', 151.46296999999998, 244.20306), ('white-rook', 702.71887, 368.35568), ('black-rook', 977.7934, 891.5799), ('black-rook', 121.77491, 461.52271), ('black-knight', 936.08838, 568.11798), ('white-pawn', 723.92841, 246.90463), ('black-knight', 246.02649, 894.48267), ('white-knight', 703.13367, 368.49414), ('white-queen', 599.25677, 155.16632)}
# -963.6821
# -963.6821 80 -13.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 3 white-pawns, 1 white-queen, 8 white-rooks, 12.4ms
# Speed: 4.0ms preprocess, 12.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 416)
# {('white-rook', 472.05865, 453.61816), ('white-pawn', 724.65558, 246.7307), ('black-pawn', 598.90125, 667.97296), ('white-pawn', 254.96344, 342.64243), ('black-rook', 978.7204, 891.54071), ('white-queen', 599.76764, 155.03577), ('black-knight', 936.5368, 567.80603), ('white-rook', 255.1559, 342.58163), ('white-king', 370.42126, 254.00178999999997), ('black-pawn', 491.60172, 566.43091), ('black-pawn', 839.36884, 782.35211), ('black-pawn', 711.60992, 791.39203), ('white-rook', 703.52032, 368.33179), ('white-knight', 107.6548, 893.02972), ('black-rook', 951.14587, 785.45239), ('white-rook', 151.76196, 243.27705), ('white-rook', 811.89355, 458.77982), ('white-rook', 116.46503, 894.14661), ('white-rook', 924.50403, 145.57693), ('white-rook', 155.54222, 133.3678), ('white-pawn', 598.96423, 557.46173), ('black-knight', 247.04059, 894.71143), ('white-knight', 704.07825, 368.38211), ('black-rook', 123.53677, 461.43399)}
# 0.0
# 0.0 80 0.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 1 black-queen, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 7 white-rooks, 12.4ms
# Speed: 3.6ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('black-knight', 936.23749, 567.33997), ('white-pawn', 597.75641, 557.91229), ('white-rook', 924.89679, 145.05545), ('white-pawn', 471.80115, 452.97986), ('black-queen', 369.3443, 896.5451), ('black-pawn', 710.95685, 791.20581), ('black-pawn', 491.48096, 566.02814), ('black-rook', 977.77808, 891.16852), ('black-pawn', 839.65625, 781.02924), ('white-rook', 702.83954, 368.30939), ('white-rook', 155.31498, 132.76424), ('white-queen', 599.73322, 154.54167), ('white-pawn', 254.74847, 342.19235), ('black-rook', 122.06287, 460.34879), ('black-rook', 951.01764, 785.14673), ('white-pawn', 724.45538, 246.43822), ('black-knight', 246.46246, 894.73444), ('white-king', 370.14304, 253.84541), ('black-pawn', 598.14441, 667.91931), ('white-rook', 811.34216, 458.30826), ('white-rook', 151.34984, 242.60786), ('white-rook', 115.0688, 893.16791), ('white-knight', 703.22632, 368.3475), ('white-rook', 472.05594, 452.72916), ('white-knight', 108.02707, 891.66498)}
# 0.0
# 0.0 80 0.0
#
# 0: 384x416 3 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 8 white-rooks, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('white-rook', 254.8336, 342.31723), ('white-rook', 925.11298, 145.11392), ('white-queen', 599.8006, 154.6891), ('white-knight', 702.9834, 368.17953), ('white-knight', 108.74147, 891.81512), ('white-pawn', 724.44031, 246.49796), ('white-pawn', 472.06931, 453.06485), ('white-rook', 151.24518, 242.96835), ('white-rook', 155.34521999999998, 133.02924), ('white-rook', 702.51666, 368.2261), ('black-pawn', 491.58978, 566.1347), ('white-pawn', 598.68848, 557.11395), ('black-knight', 246.78238, 894.56525), ('white-rook', 472.38522, 452.94107), ('white-king', 370.35196, 253.88474), ('black-rook', 977.7511, 891.01703), ('black-pawn', 598.43121, 667.901), ('black-pawn', 839.52222, 781.6756), ('black-knight', 488.86554, 903.91412), ('white-rook', 811.90289, 458.32568), ('black-rook', 951.43311, 785.10522), ('white-pawn', 254.63533, 342.35278), ('black-pawn', 711.28485, 791.20154), ('black-rook', 123.1938, 460.53488), ('black-knight', 936.24792, 567.27991), ('white-rook', 115.65207, 893.28052)}
# -997.4003
# -997.4003 80 -13.0
#
# 0: 384x416 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 5 white-rooks, 12.4ms
# Speed: 3.7ms preprocess, 12.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 416)
# {('black-rook', 977.92761, 890.63513), ('white-pawn', 597.60809, 557.25543), ('white-knight', 108.05787, 890.98248), ('white-rook', 811.95569, 457.39886), ('white-pawn', 254.73045, 342.20804), ('black-knight', 246.49138, 894.65338), ('black-pawn', 839.01794, 780.3302), ('black-pawn', 491.78085, 565.57605), ('white-queen', 600.00269, 154.03444), ('white-pawn', 472.12955, 452.53339), ('white-rook', 155.44907, 131.82683), ('black-rook', 950.50061, 784.76202), ('black-pawn', 598.69171, 667.99048), ('white-knight', 703.07776, 367.57285), ('black-knight', 936.65308, 566.25836), ('white-king', 370.58716, 253.35114), ('black-rook', 122.87076, 459.50128), ('white-pawn', 724.33636, 246.11086), ('white-rook', 151.5919, 242.08455), ('white-rook', 113.59035, 891.57971), ('black-pawn', 711.00256, 791.16479), ('white-rook', 924.41412, 143.80659)}
# 0.0
# 0.0 80 0.0
#
# 0: 384x416 2 black-knights, 5 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 2 white-queens, 7 white-rooks, 12.4ms
# Speed: 4.7ms preprocess, 12.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 416)
# {('white-knight', 702.81146, 366.06183), ('white-king', 369.37152, 253.0656), ('white-queen', 598.20471, 153.34135), ('white-knight', 106.73963, 890.38873), ('white-pawn', 471.47116, 452.15082), ('white-pawn', 254.62012, 341.8085), ('black-rook', 122.33252, 459.11102), ('white-rook', 155.16674, 132.13156), ('black-pawn', 711.31006, 790.75562), ('black-rook', 978.61627, 889.71625), ('black-rook', 950.85864, 784.53937), ('black-pawn', 598.82941, 667.10773), ('black-knight', 935.85217, 565.69855), ('white-rook', 151.50787, 241.91599), ('black-knight', 246.08531, 893.62219), ('black-pawn', 491.82669, 564.13403), ('black-pawn', 838.78461, 779.4751), ('white-rook', 924.51709, 143.34749), ('white-rook', 811.22119, 456.32938), ('white-rook', 115.5499, 892.19629), ('white-pawn', 723.13147, 245.12434), ('white-rook', 471.67343, 451.30786), ('black-pawn', 588.3551, 778.11932), ('white-pawn', 597.00769, 556.16785), ('white-rook', 254.89232, 341.64423), ('white-queen', 369.26236, 252.84587)}
# 2271.111
# 2271.111 80 28.0
#
# 0: 384x416 2 black-knights, 5 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 5 white-rooks, 12.6ms
# Speed: 3.7ms preprocess, 12.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 712.76245, 791.62653), ('white-queen', 600.10352, 153.12827), ('black-rook', 979.25079, 890.32996), ('white-knight', 109.38589, 890.7735), ('white-rook', 812.67255, 456.79468), ('white-rook', 151.9654, 241.90956), ('white-rook', 156.00735, 131.94029), ('black-pawn', 589.6972, 778.86932), ('white-king', 370.61819, 252.96866), ('white-pawn', 597.80933, 557.10297), ('white-rook', 115.45677, 892.29926), ('white-pawn', 255.15324, 342.04208), ('black-rook', 123.1637, 458.71286), ('white-pawn', 724.79358, 246.11075), ('white-rook', 924.91821, 144.07269), ('black-knight', 936.69147, 566.20654), ('black-rook', 950.87726, 784.02795), ('black-pawn', 599.36328, 668.08008), ('black-knight', 246.56718, 894.58435), ('black-pawn', 491.81714, 565.70331), ('white-pawn', 472.2941, 452.68692), ('white-knight', 703.80048, 367.25461), ('black-pawn', 839.40228, 781.08203)}
# -346.1327
# -346.1327 80 -5.0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb Cell 13 line 1
# ----> <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> main("2_move_student.mp4")
#
# /home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb Cell 13 line 2
#     <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X22sZmlsZQ%3D%3D?line=245'>246</a> differences = summarize_states(lst=state_list, tolerance=TOLERANCE)
#     <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X22sZmlsZQ%3D%3D?line=246'>247</a> uci = uci_from_differences(differences)
# --> <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X22sZmlsZQ%3D%3D?line=247'>248</a> pgn, board_states = generate_pgn(moves=uci, ori=ori)
#     <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X22sZmlsZQ%3D%3D?line=249'>250</a> return pgn, board_states
#
# /home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb Cell 13 line 1
#     <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X22sZmlsZQ%3D%3D?line=156'>157</a> # place each piece
#     <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X22sZmlsZQ%3D%3D?line=157'>158</a> for color, piece, alpha, num in ori:
# --> <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X22sZmlsZQ%3D%3D?line=159'>160</a>     sym = SYM_KEY[piece]
#     <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X22sZmlsZQ%3D%3D?line=161'>162</a>     if color == BLACK:
#     <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X22sZmlsZQ%3D%3D?line=162'>163</a>         piece = sym.lower()
#
# KeyError: 'white'
