# %% [markdown]
# # AI boys: chess detection project
#
# **Members:**
# - Kridbhume Chammanard
# - Ting-Yi Lin
# - Thana Wanavit
# - Norapath Arjanurak
# - Pattaradanai Lakkananithiphan

# %% [markdown]
# ### Import the necessary libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import mediapipe as mp
from collections import Counter
import chess
import chess.pgn

import os
import random

from PIL import Image
from ultralytics import YOLO
from dotenv import dotenv_values
from ultralytics.utils.ops import scale_image

import json

# %% [markdown]
# ### Constant Settings

# %%
# initaiate hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(min_detection_confidence=0.2, min_tracking_confidence=0.5)
# a to h from left to right
X_INDEX = list("abcdefgh")
# 8 to 1 from top to bottom
Y_INDEX = [str(i+1) for i in range(8)][::-1]
# initiate state accumulation variables
state_list = []
pgn_list = []
# noise frame tolerance
TOLERANCE = 2
# crop distance
CROP = 50
# 1/frame_rate
RATE = 1
# class names
BLACK = "black"
WHITE = "white"
KING = "king"
# promotion key for uci
PROMOTE_KEY = {"knight":"n","king":"k","bishop":"b","queen":"q","rook":"r","pawn":""}
SYM_KEY = {"knight":"n","king":"k","bishop":"b","queen":"q","rook":"r","pawn":"p"}
# model path
MODEL_PATH = "chess_model/runs/detect/chess_data_model_yolov11m_epoch50/weights/best.pt"
# Out:
# W0000 00:00:1733796875.461619   20806 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1733796875.473362   20806 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %% [markdown]
# ### Model Inference

# %%
class ChessPredicter:
    def __init__(self, model_path=MODEL_PATH):
      model = YOLO(model_path)
      self.model = model

    def predict_image(self, img):
      results = self.model(img)[0]
      return results.to_json()
    
    def format_output(self, result):
      lst = json.loads(result)
      # reformat as class, x, y, w, h
      return [(e['name'],e['box']['x1'],e['box']['y1'],e['box']['x2']-e['box']['x1'],e['box']['y2']-e['box']['y1']) for e in lst]
    
    def get_state(self, img):
       result = self.predict_image(img)
       return self.format_output(result)

# %% [markdown]
# ### Image preprocessing

# %%
class ChessboardProcessor:

    WIDTH = 640
    HEIGHT = 640

    def __init__(self, image):
        # self.image_path = image_path
        self.image = image
        self.warped_image = None
        self.transformation_matrix = None

    # Utility function to display images
    def display_image(self, img, title="Image"):
        plt.figure(figsize=(6, 6))
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.title(title)
        plt.show()

    # Reorders points to top-left, top-right, bottom-right, bottom-left
    def reorder(self, pts):
        pts = pts.reshape((4, 2))
        new_pts = np.zeros((4, 1, 2), dtype="float32")
        sum_pts = pts.sum(1)
        new_pts[0] = pts[np.argmin(sum_pts)]  # Top-left
        new_pts[3] = pts[np.argmax(sum_pts)]  # Bottom-right
        diff_pts = np.diff(pts, axis=1)
        new_pts[1] = pts[np.argmin(diff_pts)]  # Top-right
        new_pts[2] = pts[np.argmax(diff_pts)]  # Bottom-left
        return new_pts

    # Preprocess the image (grayscale, blur, threshold, morphology)
    def preprocess(self):
        img_gray = cv2.cvtColor(self.image, cv2.COLOR_BGR2GRAY)
        img_blur = cv2.GaussianBlur(img_gray, (3, 3), 1)
        img_threshold = cv2.adaptiveThreshold(img_blur, 255, 1, 1, 15, 2)

        # Morphological operations
        # kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
        # img_opening = cv2.morphologyEx(img_threshold, cv2.MORPH_OPEN, kernel)
        # img_closing = cv2.morphologyEx(img_opening, cv2.MORPH_CLOSE, kernel)

        # self.display_image(img_threshold, "Preprocessed Image")
        return img_threshold

    # Finds the largest contour with 4 points
    def find_biggest_contour(self, contours):
        largest_pts = None
        max_area = 0
        for contour in contours:
            area = cv2.contourArea(contour)
            if area > 50:  # Ignore small contours
                peri = cv2.arcLength(contour, True)
                approx = cv2.approxPolyDP(contour, 0.1 * peri, True)
                if area > max_area and len(approx) == 4:
                    largest_pts = approx
                    max_area = area
        return self.reorder(largest_pts) if largest_pts is not None else None, max_area

    # Finds the chessboard corners and returns the reordered corners
    def find_board_corners(self):
        processed_img = self.preprocess()
        contours, _ = cv2.findContours(processed_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        contour_img = self.image.copy()
        cv2.drawContours(contour_img, contours, -1, (0, 255, 0), 3)
        # self.display_image(contour_img, "Image with Contours")
        corners, _ = self.find_biggest_contour(contours)
        return corners

    # Applies perspective transformation to get a bird's-eye view
    def warp_image(self, corners):
        original_pts = np.float32(corners)
        new_pts = np.float32([[0, 0], [self.WIDTH, 0], [0, self.HEIGHT], [self.WIDTH, self.HEIGHT]])
        self.transformation_matrix = cv2.getPerspectiveTransform(original_pts, new_pts)
        self.warped_image = cv2.warpPerspective(self.image, self.transformation_matrix, (self.WIDTH, self.HEIGHT))
        return self.warped_image

    # Draws points on the given image
    def draw_points(self, img, pts, color=(0, 0, 255), size=10):
        for pt in pts:
            pt = tuple(map(int, pt))  # Convert to (x, y) tuple
            cv2.circle(img, pt, size, color, -1)

    # Generates random points within the image dimensions
    def generate_random_points(self, num_points=4):
        height, width, _ = self.image.shape
        
        # Generate random points
        random_points = [(random.randint(0, width - 1), random.randint(0, height - 1)) for _ in range(num_points)]
        random_points = np.float32(random_points)
        
        # Create a list of tuples with (piece, x_coord, y_coord)
        piece_list = []
        for i, (x_coord, y_coord) in enumerate(random_points, start=1):
            piece_list.append((f"piece {i}", x_coord, y_coord))
        
        return piece_list
    
    # Main function to process the image
    def rotate_and_warp(self, detection_cg):
        # Find the chessboard corners in the frame
        corners = self.find_board_corners()
        if corners is not None:
            # Copy the original image for visualization
            image_with_points = self.image.copy()

            # Draw the original detection CG points on the original image
            for piece, x_coord, y_coord in detection_cg:
                self.draw_points(image_with_points, [(x_coord, y_coord)])

            # Warp the image based on the detected chessboard corners
            warped_image = self.warp_image(corners)

            # Prepare the original detection CG points for transformation
            original_points = np.array([[x, y] for _, x, y in detection_cg], dtype=np.float32).reshape(-1, 1, 2)

            # Apply perspective transformation to the original points
            transformed_points = cv2.perspectiveTransform(original_points, self.transformation_matrix)

            # Prepare the transformed points as a list of tuples (piece, x_new, y_new)
            transformed_points_list = []
            for i, (piece, _, _) in enumerate(detection_cg):  # Correct unpacking here
                x_new, y_new = transformed_points[i][0]
                transformed_points_list.append((piece, x_new, y_new))

            # Draw the transformed points on the warped image
            self.draw_points(warped_image, transformed_points[:, 0])

            # Display the original image with points and the warped image with transformed points
            # plt.figure(figsize=(12, 6))
            # plt.subplot(1, 2, 1)
            # plt.imshow(cv2.cvtColor(image_with_points, cv2.COLOR_BGR2RGB))
            # plt.title("Original Image with Detection Points")
            # plt.axis('off')

            # plt.subplot(1, 2, 2)
            # plt.imshow(cv2.cvtColor(warped_image, cv2.COLOR_BGR2RGB))
            # plt.title("Warped Image with Transformed Points")
            # plt.axis('off')

            # plt.show()

            return warped_image, transformed_points_list
        else:
            print("Could not find the corners of the chessboard.")
            return None, None

# %% [markdown]
# ### Program loop

# %%
# wrap the video reader
def frame_generator(video_path):
    # Open the video file
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print("Error: Could not open video file.")
        return

    while True:
        ret, frame = cap.read()
        if not ret:
            break  # End of video
        yield frame  # Yield frame to the caller

    cap.release()

# Function to check if hands are detected in a frame
def hands_detected(frame):
    # Convert the frame to RGB as MediaPipe uses RGB
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    
    # Process the frame and get the result
    results = hands.process(rgb_frame)
    
    # If hands are detected, results.multi_hand_landmarks will not be None
    return results.multi_hand_landmarks is not None

# summarize state list into easy to use format
def summarize_states(lst, tolerance):

    # Step 1: Clean the state list of noises
    # initialize counters
    state_counter = 1
    previous = None
    updated = False
    summarized_states = []
    # loop through the list
    for state in lst:

        # if new state detected
        if previous is None or state != previous:
            state_counter = 1
            updated = False

        # if the count of state reaches tolerance
        if state_counter >= tolerance and not updated:
            # print("Noted")
            summarized_states.append(state)
            updated = True

        # print(f"state = {state}\nprevious = {previous}\nstate_counter={state_counter}\nupdated={updated}","\n")

        # iterate the counters
        state_counter += 1
        previous = state
    # print(f"Summarized:", summarized_states)

    # Step 2: Identify differences between consecutive states
    differences = []
    for i in range(len(summarized_states) - 1):
        old_state = summarized_states[i]
        new_state = summarized_states[i + 1]
        
        disappeared = old_state - new_state
        appeared = new_state - old_state
        
        differences.append((disappeared, appeared))
    # print("Differences:", differences)

    return differences

def uci_from_differences(differences):

    """
    Convert the output of summarize_states into UCI format.

    Parameters:
        differences (list): List of differences as ({disappeared}, {appeared}).

    Returns:
        list: A list of UCI moves
    """

    uci_moves = []

    for disappeared, appeared in differences:

        l_d = len(disappeared)
        l_a = len(appeared)


        print("appeared:", appeared)
        print("disappeared:", disappeared)
        print("l_a:",l_a)
        print("l_d:", l_d)

        if l_d == 1 and l_a == 1: # movement or promotion

            print("triggered case 1")

            old = list(disappeared)[0]
            new = list(appeared)[0]

            if old[:2] == new[:2]: # if the class and color is the same -> movement
                msg = f"{old[2]}{old[3]}{new[2]}{new[3]}"

            else: # promotion
                msg = f"{old[2]}{old[3]}{new[2]}{new[3]}{PROMOTE_KEY[new[1]]}"

        elif l_d == 2 and l_a == 1: # capturing

            print("triggered case 2")

            new = list(appeared)[0]
            old = [piece for piece in disappeared if piece[:2] == new[:2]][0] # the capturer

            msg = f"{old[2]}{old[3]}{new[2]}{new[3]}"

        elif l_d == 2 and l_a == 2: # castling

            print("triggered case 3")

            new_king = [piece for piece in appeared if piece[:2] == KING][0]

            if new_king[2] == "g": # king side
                if new_king[0] == BLACK:
                    msg = "e8g8"
                else:
                    msg = "e1g1"
            elif new_king[2] == "c": # queen side
                if new_king[0] == BLACK:
                    msg = "e8c8"
                else:
                    msg = "e1c1"
            else:
                msg = "CASTLING_ERROR"

        else:
            msg = "MOVE_ERROR"

        uci_moves.append(msg)
     
    return uci_moves

def generate_pgn(moves, ori):

    """
    Convert UCI moves on a board to PGN and also output board state 

    Parameters:
        moves (list) : List of UCI moves in the game
        ori (list) : List of pieces on the board. Each piece is structured as (color, class, alphabet, num)

    Returns:
        pgn (str) : A string of PGN of the game
        board_states (list) : a list of board states. Each state is a string
    
    """

    # initialize board
    board = chess.Board()

    # if there is a predetermined starting point
    if ori is not None:
        board.clear()

        # place each piece
        for color, piece, alpha, num in ori:

            sym = SYM_KEY[piece]

            if color == BLACK:
                piece = sym.lower()
            elif color == WHITE:
                piece = sym.upper()

            position = alpha + str(num)
            square = chess.parse_square(position)
            board.set_piece_at(square, chess.Piece.from_symbol(sym))

    # create game
    game = chess.pgn.Game()
    node = game
    node.headers["FEN"] = board.fen()

    # iterate through UCI and keep track of board state
    board_states = list()
    board_states.append(board)
    for move in moves:
        try:
            node = node.add_variation(board.parse_uci(move))
            board.push_uci(move)
            board_states.append(board)
        except ValueError:
            print(f"Move {move} is invalid")
    
    pgn = str(game).split("\n")[-1]
    return pgn, board_states

# main
def main(video_path):

    predictor = ChessPredicter()

    for i, frame in enumerate(frame_generator(video_path)):
            
        if i % RATE == 0

            frame = frame[:,:,::-1]

            h,w,_ = frame.shape
            delta = (h-w)//2
            frame = frame[delta+CROP:delta+w-CROP,:,:]

            # plt.imshow(frame)
            # plt.show()

            # if hand is there
            if not hands_detected(frame):

                # detect pieces and format the piece's foot CG
                detection = predictor.get_state(frame)
                detection_cg = {(piece_class,x+w//2,y+h) for piece_class,x,y,w,h in detection}
                print(detection_cg)

                # get the transformed image and the coordinate of the transformed CG
                chessboard = ChessboardProcessor(frame)
                img, piece_cg = chessboard.rotate_and_warp(detection_cg)
                if img is None or piece_cg is None: # if the frame is bad skip it
                    continue
                # print(piece_cg[0][1])

                # get the image size to divide into cells
                shape = img.shape
                x_cell_size = shape[0]//8
                y_cell_size = shape[1]//8
                # print(x, x_cell_size, x//x_cell_size)
                

                # img, {(white-knight,x,y),(black-queen,x1,y1)}
                print(piece_cg)

                # reformat the piece_cg set to indicate row and column instead
                detection_cell = {(piece_class.split("-")[0], # color
                                piece_class.split("-")[1], # class
                                X_INDEX[int(x//x_cell_size) % 8], # column: a,b,c..
                                Y_INDEX[int(y//y_cell_size) % 8]) # row: 1,2,...
                                for piece_class,x,y in piece_cg}
                
                state_list.append(detection_cell)

    # Original state
    ori = state_list[0]
        
    # Once the processing is finished
    differences = summarize_states(lst=state_list, tolerance=TOLERANCE)
    print("differences:", differences)
    uci = uci_from_differences(differences)
    pgn, board_states = generate_pgn(moves=uci, ori=ori)

    return pgn, board_states

# %%
pgn, boards = main("2_move_student.mp4")
# Out:
# 0: 384x416 2 black-knights, 3 black-pawns, 1 black-queen, 3 black-rooks, 1 white-king, 2 white-knights, 3 white-pawns, 1 white-queen, 6 white-rooks, 114.0ms
# Speed: 3.7ms preprocess, 114.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('black-knight', 936.41443, 567.46136), ('black-pawn', 491.19223, 566.2179), ('black-queen', 369.90723, 896.33148), ('black-rook', 122.64418, 460.69983), ('white-king', 370.86295, 253.25815), ('black-knight', 247.11687, 894.57544), ('white-rook', 812.43512, 458.42993), ('black-pawn', 840.44659, 782.34961), ('white-rook', 703.06433, 368.11996), ('white-rook', 151.54055, 242.59029), ('white-knight', 703.54462, 368.05319), ('white-rook', 925.37836, 144.99403), ('white-rook', 155.41771, 131.78552), ('white-pawn', 254.84706, 342.2077), ('white-queen', 599.80066, 154.17502), ('white-knight', 105.85122, 892.08862), ('black-pawn', 598.91907, 667.84863), ('black-rook', 952.66235, 785.38202), ('white-pawn', 598.7099, 557.09991), ('white-rook', 472.6915, 453.27722), ('white-pawn', 724.54028, 246.51593), ('black-rook', 978.59058, 891.14789)}
# [('black-knight', 0.0, 0.0), ('black-pawn', 0.0, 0.0), ('black-queen', 0.0, 0.0), ('black-rook', 0.0, 0.0), ('white-king', 0.0, 0.0), ('black-knight', 0.0, 0.0), ('white-rook', 0.0, 0.0), ('black-pawn', 0.0, 0.0), ('white-rook', 0.0, 0.0), ('white-rook', 0.0, 0.0), ('white-knight', 0.0, 0.0), ('white-rook', 0.0, 0.0), ('white-rook', 0.0, 0.0), ('white-pawn', 0.0, 0.0), ('white-queen', 0.0, 0.0), ('white-knight', 0.0, 0.0), ('black-pawn', 0.0, 0.0), ('black-rook', 0.0, 0.0), ('white-pawn', 0.0, 0.0), ('white-rook', 0.0, 0.0), ('white-pawn', 0.0, 0.0), ('black-rook', 0.0, 0.0)]
#
# 0: 384x416 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 6 white-rooks, 124.3ms
# Speed: 4.0ms preprocess, 124.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('black-rook', 123.0422, 460.55167), ('white-rook', 812.68536, 457.81851), ('white-rook', 925.03467, 144.0497), ('white-king', 371.15344, 253.18007), ('white-pawn', 599.03943, 556.83667), ('white-queen', 599.72632, 154.14706), ('black-pawn', 599.57361, 667.32263), ('white-rook', 155.52589, 131.96515), ('black-knight', 247.14865, 894.33984), ('white-rook', 151.65211, 242.58006), ('white-pawn', 254.93085, 342.06332), ('white-knight', 703.93402, 367.74454), ('black-rook', 978.56805, 890.97186), ('white-rook', 703.39459, 367.88174), ('white-pawn', 473.29416, 453.04398), ('white-knight', 108.04957, 891.11426), ('black-pawn', 711.46802, 791.35614), ('black-knight', 936.68524, 566.85303), ('black-pawn', 491.23621, 566.08337), ('black-pawn', 840.89313, 781.89587), ('white-pawn', 724.45496, 246.35463), ('black-rook', 951.57886, 785.08746), ('white-rook', 472.5864, 452.97287)}
# [('black-rook', -3089.9182, -65.3676), ('white-rook', 925.9569, -120.932), ('white-rook', 1643.2664, -2118.864), ('white-king', -1664.6952, -1380.8269), ('white-pawn', -321.9682, 496.79425), ('white-queen', -306.45673, -2033.2493), ('black-pawn', -321.90277, 1160.5754), ('white-rook', -2967.248, -2150.755), ('black-knight', -2305.3203, 2503.7268), ('white-rook', -2967.4749, -1435.6122), ('white-pawn', -2340.1194, -810.44867), ('white-knight', 299.3542, -675.0747), ('black-rook', 1801.5701, 2447.6948), ('white-rook', 296.17426, -674.1836), ('white-pawn', -1051.9017, -131.32574), ('white-knight', -3085.8567, 2492.2405), ('black-pawn', 308.48743, 1885.2795), ('black-knight', 1627.5951, 539.0439), ('black-pawn', -944.3727, 558.7201), ('black-pawn', 1043.099, 1823.3987), ('white-pawn', 431.27042, -1445.4414), ('black-rook', 1670.3071, 1836.3138), ('white-rook', -1056.0281, -131.7249)]
#
# 0: 384x416 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 6 white-rooks, 115.3ms
# Speed: 4.3ms preprocess, 115.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('black-rook', 951.49237, 784.94373), ('white-pawn', 724.51495, 246.17644), ('white-king', 370.77426, 253.12723), ('black-knight', 936.84857, 566.41595), ('white-pawn', 473.28394, 452.81625), ('black-pawn', 599.47375, 667.30157), ('white-queen', 599.67841, 153.87915), ('white-rook', 472.59091, 452.58463), ('white-rook', 151.52787999999998, 242.25558), ('white-rook', 925.11707, 143.90614), ('black-pawn', 839.89453, 781.54938), ('white-knight', 107.84886, 890.92224), ('white-rook', 155.31637999999998, 131.78183), ('black-rook', 978.3136, 890.93121), ('white-rook', 703.05383, 367.7045), ('white-knight', 703.59375, 367.48785), ('black-rook', 123.18609, 459.57742), ('black-knight', 246.81073, 894.31873), ('black-pawn', 491.27481, 565.78595), ('white-pawn', 597.60089, 557.38959), ('white-pawn', 254.87259, 341.93811), ('white-rook', 813.04297, 457.12766), ('black-pawn', 711.2038, 791.33191)}
# [('black-rook', 3524.5864, 1165.5942), ('white-pawn', 2429.1719, -2120.9692), ('white-king', 309.74683, -2052.5916), ('black-knight', 3543.922, -102.56811), ('white-pawn', 913.485, -772.435), ('black-pawn', 1609.247, 511.39105), ('white-queen', 1697.3203, -2739.9414), ('white-rook', 909.48645, -773.839), ('white-rook', -1003.338, -2111.475), ('white-rook', 3686.865, -2830.2263), ('black-pawn', 2912.5056, 1151.9182), ('white-knight', -1073.8608, 1788.5114), ('white-rook', -1011.991, -2863.7395), ('black-rook', 3622.3083, 1748.9102), ('white-rook', 2266.4834, -1323.692), ('white-knight', 2269.715, -1325.1136), ('black-rook', -1107.7034, -710.7598), ('black-knight', -325.13892, 1800.5576), ('black-pawn', 1010.62103, -82.6044), ('white-pawn', 1615.9551, -138.76122), ('white-pawn', -367.66272, -1463.103), ('white-rook', 2879.2258, -764.68396), ('black-pawn', 2202.9622, 1212.875)]
#
# 0: 384x416 2 black-knights, 4 black-pawns, 1 black-queen, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 4 white-rooks, 116.7ms
# Speed: 4.3ms preprocess, 116.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('black-queen', 369.15192, 895.75818), ('black-knight', 246.52124, 894.22168), ('black-pawn', 490.93887, 565.73273), ('black-rook', 978.36334, 890.99115), ('black-rook', 951.74377, 784.98383), ('white-rook', 154.73282, 132.10719), ('white-rook', 925.62964, 144.68961), ('black-rook', 122.41281, 459.82767), ('white-pawn', 598.72052, 556.66101), ('white-knight', 105.44498, 891.08685), ('white-pawn', 724.21893, 246.22447), ('white-king', 369.76318, 253.53511), ('white-pawn', 254.61931, 342.04184), ('white-rook', 811.5235, 457.0332), ('white-rook', 151.18252, 242.14867), ('white-knight', 702.31647, 367.3587), ('white-queen', 598.73529, 153.86331), ('black-pawn', 598.72418, 667.16656), ('white-pawn', 471.52652, 452.81116), ('black-knight', 936.32007, 566.62549), ('black-pawn', 710.53284, 791.31445), ('black-pawn', 839.66217, 780.87469)}
# [('black-queen', 339.1606, 1802.7362), ('black-knight', -321.32825, 1800.0009), ('black-pawn', 1014.39545, -82.95925), ('black-rook', 3627.9573, 1749.1875), ('black-rook', 3531.4475, 1165.759), ('white-rook', -1009.35767, -2861.5093), ('white-rook', 3695.6938, -2824.8933), ('black-rook', -1106.3237, -709.2196), ('white-pawn', 1628.1335, -143.26268), ('white-knight', -1081.3732, 1789.4651), ('white-pawn', 2433.3801, -2120.692), ('white-king', 309.70367, -2049.8748), ('white-pawn', -363.25043, -1462.4774), ('white-rook', 2876.2522, -765.24316), ('white-rook', -999.4518, -2112.2297), ('white-knight', 2268.1213, -1325.926), ('white-queen', 1697.6697, -2740.0544), ('black-pawn', 1610.6678, 510.59366), ('white-pawn', 909.1038, -772.4242), ('black-knight', 3546.507, -101.33335), ('black-pawn', 2204.7712, 1212.7616), ('black-pawn', 2916.967, 1148.0955)]
#
# 0: 384x416 2 black-knights, 4 black-pawns, 1 black-queen, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 6 white-rooks, 119.0ms
# Speed: 3.8ms preprocess, 119.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('white-pawn', 254.27539, 342.18573), ('black-queen', 369.10114, 896.34235), ('white-queen', 598.53198, 154.13892), ('black-pawn', 839.49475, 780.77777), ('white-pawn', 471.36514, 452.87048), ('black-rook', 951.43164, 785.03455), ('black-pawn', 710.29321, 791.19238), ('black-rook', 121.73983, 459.94708), ('white-rook', 155.34349, 132.91747), ('black-knight', 246.01205, 894.46057), ('black-pawn', 597.78961, 667.56232), ('white-pawn', 597.24731, 557.8092), ('white-rook', 810.81097, 457.98941), ('black-rook', 977.26318, 891.2406), ('white-rook', 924.40796, 144.92194), ('white-knight', 702.62714, 368.01843), ('white-rook', 702.34485, 368.17108), ('white-pawn', 723.96887, 246.61861), ('black-pawn', 490.73209, 565.8653), ('white-rook', 112.33293, 892.97644), ('black-knight', 935.81586, 567.21979), ('white-knight', 105.56587, 891.66437), ('white-king', 369.14319, 253.74429), ('white-rook', 151.51279, 242.39856)}
# [('white-pawn', -111.64553, 640.0), ('black-queen', -18.732594, 640.0), ('white-queen', 61.60708, 640.0), ('black-pawn', -39.332043, 640.0), ('white-pawn', 411.1674, 640.0), ('black-rook', -39.939163, 640.0), ('black-pawn', -39.805576, 640.0), ('black-rook', -70.23038, 640.0), ('white-rook', -113.47908, 640.0), ('black-knight', -29.845207, 640.0), ('black-pawn', -11.097488, 640.0), ('white-pawn', 9.437206, 640.0), ('white-rook', -13.82857, 640.0), ('black-rook', -46.2401, 640.0), ('white-rook', -3.9522595, 640.0), ('white-knight', 6.1654615, 640.0), ('white-rook', 6.202308, 640.0), ('white-pawn', 12.513305, 640.0), ('black-pawn', 183.6462, 640.0), ('white-rook', -33.778862, 640.0), ('black-knight', -26.859589, 640.0), ('white-knight', -33.994663, 640.0), ('white-king', -300.15323, 640.0), ('white-rook', -98.223976, 640.0)]
#
# 0: 384x416 3 black-knights, 3 black-pawns, 1 black-queen, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 5 white-rooks, 123.9ms
# Speed: 4.1ms preprocess, 123.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('black-queen', 369.56839, 896.20801), ('black-rook', 951.50287, 785.38757), ('white-rook', 155.81345, 133.2917), ('white-pawn', 254.63762, 342.58099), ('white-queen', 598.46765, 154.50366), ('white-knight', 702.79449, 368.46774), ('black-pawn', 490.78802, 566.09656), ('white-rook', 150.65949, 242.80692), ('black-knight', 246.5816, 894.4577), ('black-rook', 121.90082, 461.08353), ('white-king', 369.77783, 254.04912000000002), ('white-rook', 471.98227, 453.16724), ('black-rook', 977.66956, 891.48859), ('white-rook', 923.43616, 145.06366), ('black-knight', 488.31937, 904.10663), ('white-rook', 811.39209, 458.97827), ('white-pawn', 598.26141, 557.341), ('white-pawn', 724.14227, 246.88779), ('white-pawn', 471.74377, 453.21735), ('white-knight', 104.60815, 892.03699), ('black-knight', 935.85016, 567.85114), ('black-pawn', 598.13422, 667.72009), ('black-pawn', 839.74426, 782.17816)}
# [('black-queen', -1630.9352, 1179.1823), ('black-rook', 1666.2548, 544.073), ('white-rook', -2933.1802, -3435.4885), ('white-pawn', -2323.0833, -2111.007), ('white-queen', -285.36227, -3299.1064), ('white-knight', 309.1288, -1950.3951), ('black-pawn', -940.6, -746.70044), ('white-rook', -2948.4941, -2736.5994), ('black-knight', -2322.4036, 1169.2386), ('black-rook', -3085.8425, -1381.4016), ('white-king', -1648.6604, -2665.5847), ('white-rook', -1047.0133, -1429.6951), ('black-rook', 1788.427, 1152.3645), ('white-rook', 1658.6663, -3359.7402), ('black-knight', -963.62195, 1224.0201), ('white-rook', 929.75024, -1394.2385), ('white-pawn', -319.4357, -799.2012), ('white-pawn', 451.95877, -2710.806), ('white-pawn', -1048.4039, -1429.3892), ('white-knight', -3120.92, 1155.4818), ('black-knight', 1628.4523, -736.18854), ('black-pawn', -328.787, -142.80765), ('black-pawn', 1033.0366, 525.511)]
#
# 0: 384x416 3 black-knights, 3 black-pawns, 1 black-queen, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 6 white-rooks, 125.2ms
# Speed: 4.2ms preprocess, 125.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('white-pawn', 598.38318, 557.57373), ('white-rook', 811.90564, 459.00851), ('white-king', 370.22382, 254.27956), ('white-rook', 924.75958, 145.24747), ('white-rook', 155.35435, 133.62448), ('black-rook', 123.18272, 461.33517), ('white-pawn', 254.60851, 342.47678), ('black-rook', 951.56335, 785.46857), ('black-knight', 245.98083, 894.50159), ('white-pawn', 724.51526, 247.01733), ('black-pawn', 598.6673, 667.80566), ('black-pawn', 840.2077, 782.57513), ('white-knight', 703.83374, 368.32538), ('black-knight', 489.04214, 904.27283), ('white-queen', 599.01508, 154.68861), ('white-rook', 150.86284999999998, 242.89413), ('white-rook', 472.38593, 453.57385), ('white-pawn', 472.15448, 453.45551), ('black-pawn', 490.94266, 566.32831), ('white-rook', 703.42786, 368.30124), ('black-queen', 369.78067, 896.90796), ('black-rook', 978.56897, 891.63837), ('black-knight', 936.24646, 567.99725), ('white-knight', 106.36908, 892.55719)}
# [('white-pawn', 1609.5312, -134.30681), ('white-rook', 2827.9895, -730.4542), ('white-king', 318.36142, -2000.0388), ('white-rook', 3542.5464, -2694.0405), ('white-rook', -936.5733, -2768.7744), ('black-rook', -1076.5714, -716.2709), ('white-pawn', -341.12576, -1447.8234), ('black-rook', 3542.0994, 1208.1106), ('black-knight', -345.461, 1833.2328), ('white-pawn', 2362.4597, -2045.871), ('black-pawn', 1602.496, 521.17725), ('black-pawn', 2927.7354, 1191.3733), ('white-knight', 2227.054, -1287.5068), ('black-knight', 984.8385, 1888.7278), ('white-queen', 1646.0668, -2633.443), ('white-rook', -948.11255, -2071.9175), ('white-rook', 903.114, -763.6049), ('white-pawn', 901.8037, -764.32715), ('black-pawn', 1004.99567, -81.81897), ('white-rook', 2224.7385, -1287.6562), ('black-queen', 332.30276, 1846.9076), ('black-rook', 3665.5593, 1816.9551), ('black-knight', 3507.337, -71.82133), ('white-knight', -1109.9932, 1822.1794)]
#
# 0: 384x416 2 black-knights, 3 black-pawns, 1 black-queen, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 6 white-rooks, 126.1ms
# Speed: 4.0ms preprocess, 126.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('white-queen', 599.95569, 154.94012), ('white-knight', 703.79352, 368.41165), ('white-rook', 703.29761, 368.34677), ('white-rook', 473.01666, 453.54089), ('black-knight', 936.22412, 568.03522), ('black-pawn', 491.19647, 566.41205), ('white-pawn', 724.67401, 246.96185), ('white-rook', 151.51427, 242.98386), ('white-pawn', 472.68341, 453.36765), ('white-pawn', 255.21703, 342.72693), ('black-pawn', 599.1582, 667.82404), ('black-queen', 369.78598, 897.04486), ('black-pawn', 840.59393, 782.38245), ('white-king', 370.89859, 254.26315), ('white-rook', 924.63739, 145.5321), ('black-knight', 247.28409, 894.38104), ('black-rook', 123.67213, 461.21875), ('black-rook', 951.94501, 785.44189), ('white-pawn', 598.87091, 557.39667), ('white-rook', 155.86016, 133.46556), ('white-rook', 812.4917, 459.0166), ('white-knight', 108.18369, 892.01434), ('black-rook', 978.9162, 891.62231)}
# [('white-queen', 355.30737, -1352.1711), ('white-knight', 947.4486, -31.495064), ('white-rook', 944.5667, -31.870224), ('white-rook', -400.18076, 510.54712), ('black-knight', 2288.6143, 1195.8634), ('black-pawn', -300.77432, 1210.9174), ('white-pawn', 1075.8068, -787.3808), ('white-rook', -2259.0105, -779.72156), ('white-pawn', -402.11005, 509.48935), ('white-pawn', -1661.2303, -165.76248), ('black-pawn', 321.6931, 1835.0067), ('black-queen', -1025.9032, 3272.375), ('black-pawn', 1720.0624, 2533.2495), ('white-king', -983.11707, -722.0239), ('white-rook', 2245.0627, -1428.9758), ('black-knight', -1738.5538, 3262.742), ('black-rook', -2433.344, 577.99365), ('black-rook', 2367.8076, 2545.971), ('white-pawn', 326.25974, 1148.8118), ('white-rook', -2227.5361, -1460.5292), ('white-rook', 1574.8118, 525.39624), ('white-knight', -2547.803, 3255.893), ('black-rook', 2518.7463, 3204.2673)]
#
# 0: 384x416 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 6 white-rooks, 121.2ms
# Speed: 4.3ms preprocess, 121.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 491.28986, 566.24817), ('black-rook', 978.5993, 891.4071), ('white-rook', 151.53346, 242.64784), ('white-pawn', 472.60443, 453.23422), ('white-rook', 155.93085000000002, 133.38617), ('white-pawn', 724.57135, 246.74385), ('white-king', 371.0368, 253.9655), ('white-pawn', 599.07904, 557.12775), ('white-rook', 924.6452, 145.35028), ('black-rook', 122.96797, 460.78342), ('black-knight', 247.44489, 894.22748), ('black-pawn', 840.82721, 782.04047), ('black-pawn', 599.18707, 667.8891), ('black-knight', 936.16931, 567.75482), ('black-pawn', 711.4845, 791.47601), ('white-pawn', 255.1526, 342.5351), ('black-rook', 951.73859, 785.21985), ('white-knight', 108.5731, 891.41235), ('white-queen', 600.12177, 154.45798), ('white-rook', 472.93802, 453.22882), ('white-rook', 812.40759, 458.83685), ('white-knight', 703.7962, 368.17175), ('white-rook', 703.28613, 368.17221)}
# [('black-pawn', -943.4802, -745.792), ('black-rook', 1788.0519, 1151.9014), ('white-rook', -2949.264, -2737.6052), ('white-pawn', -1049.2163, -1429.2861), ('white-rook', -2938.4497, -3434.8801), ('white-pawn', 448.59503, -2711.7153), ('white-king', -1647.1285, -2666.1123), ('white-pawn', -320.47256, -800.48083), ('white-rook', 1659.8447, -3357.898), ('black-rook', -3085.4963, -1383.2313), ('black-knight', -2323.1914, 1167.9305), ('black-pawn', 1033.5328, 524.71436), ('black-pawn', -328.49744, -141.81165), ('black-knight', 1624.545, -736.7655), ('black-pawn', 298.59387, 579.25995), ('white-pawn', -2325.9397, -2111.2925), ('black-rook', 1661.96, 543.1032), ('white-knight', -3104.339, 1151.9312), ('white-queen', -281.4501, -3299.3997), ('white-rook', -1047.2723, -1429.3191), ('white-rook', 929.8664, -1395.1011), ('white-knight', 309.17804, -1952.2277), ('white-rook', 306.1846, -1952.2249)]
#
# 0: 384x416 2 black-knights, 4 black-pawns, 1 black-queen, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 5 white-rooks, 121.5ms
# Speed: 3.9ms preprocess, 121.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 840.55273, 781.70416), ('white-pawn', 599.1192, 557.00372), ('white-rook', 812.30664, 458.22424), ('white-queen', 599.80957, 154.30179), ('white-pawn', 254.86508, 342.27863), ('white-pawn', 724.30035, 246.53551), ('white-pawn', 473.03424, 453.02133), ('white-knight', 107.14835, 891.43042), ('black-rook', 122.5905, 460.45572), ('black-pawn', 598.80414, 667.75586), ('white-rook', 151.21753999999999, 242.49937), ('black-knight', 247.16238, 894.34521), ('black-knight', 936.36578, 567.1131), ('white-knight', 702.87738, 367.96228), ('white-rook', 702.48163, 368.03702), ('black-pawn', 711.10785, 791.21008), ('black-rook', 952.05511, 784.99365), ('white-rook', 155.58157, 133.23166), ('black-queen', 369.52121, 896.30756), ('white-king', 370.37589, 253.93991), ('black-pawn', 491.09546, 565.95593), ('white-rook', 925.23993, 145.01009), ('black-rook', 978.35907, 891.2627)}
# [('black-pawn', 0.0, 0.0), ('white-pawn', 0.0, 0.0), ('white-rook', 0.0, 0.0), ('white-queen', 0.0, 0.0), ('white-pawn', 0.0, 0.0), ('white-pawn', 0.0, 0.0), ('white-pawn', 0.0, 0.0), ('white-knight', 0.0, 0.0), ('black-rook', 0.0, 0.0), ('black-pawn', 0.0, 0.0), ('white-rook', 0.0, 0.0), ('black-knight', 0.0, 0.0), ('black-knight', 0.0, 0.0), ('white-knight', 0.0, 0.0), ('white-rook', 0.0, 0.0), ('black-pawn', 0.0, 0.0), ('black-rook', 0.0, 0.0), ('white-rook', 0.0, 0.0), ('black-queen', 0.0, 0.0), ('white-king', 0.0, 0.0), ('black-pawn', 0.0, 0.0), ('white-rook', 0.0, 0.0), ('black-rook', 0.0, 0.0)]
#
# 0: 384x416 3 black-knights, 4 black-pawns, 2 black-queens, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 5 white-rooks, 113.9ms
# Speed: 4.0ms preprocess, 113.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('white-pawn', 597.70007, 557.88409), ('white-queen', 598.62964, 154.31647), ('black-pawn', 598.19519, 667.13086), ('black-pawn', 839.5318, 780.83368), ('white-knight', 105.57212, 891.40143), ('black-rook', 977.96454, 891.09283), ('black-knight', 934.49915, 567.17401), ('black-queen', 488.02698, 903.93121), ('white-pawn', 723.95575, 246.69687), ('white-rook', 150.88438, 242.42232), ('black-rook', 121.74099, 460.43051), ('white-pawn', 471.57263, 453.03107), ('white-knight', 702.76855, 368.09152), ('white-rook', 924.34985, 145.22412), ('white-rook', 114.63235, 893.03491), ('white-king', 369.51459, 254.11678), ('black-pawn', 710.33374, 791.29901), ('white-rook', 155.07835, 133.3024), ('black-pawn', 491.44547, 565.71826), ('black-knight', 246.47987, 894.46783), ('white-pawn', 254.50171, 342.32684), ('black-knight', 950.99054, 784.22174), ('black-queen', 369.10223, 896.5697), ('white-rook', 810.9306, 458.11487), ('black-rook', 951.49188, 785.10419)}
# [('white-pawn', -322.064, -808.83105), ('white-queen', -294.60782, -3481.4785), ('black-pawn', -324.65292, -147.25642), ('black-pawn', 1030.0542, 526.15405), ('white-knight', -2913.0347, 1096.6548), ('black-rook', 1789.3918, 1170.6069), ('black-knight', 1661.5486, -772.7108), ('black-queen', -927.87585, 1197.1339), ('white-pawn', 467.9925, -2866.3594), ('white-rook', -2915.4753, -2759.0305), ('black-rook', -2989.903, -1366.3762), ('white-pawn', -1046.1614, -1452.166), ('white-knight', 316.4907, -2036.4238), ('white-rook', 1775.9734, -3650.0088), ('white-rook', -2866.7527, 1106.1006), ('white-king', -1660.6891, -2731.0635), ('black-pawn', 293.88776, 581.13983), ('white-rook', -2935.588, -3495.8054), ('black-pawn', -926.26544, -754.0778), ('black-knight', -2194.3257, 1124.7164), ('white-pawn', -2298.2292, -2127.4119), ('black-knight', 1674.7451, 550.8041), ('black-queen', -1557.1005, 1146.5269), ('white-rook', 950.29913, -1460.5409), ('black-rook', 1677.3347, 556.0145)]
#
# 0: 384x416 3 black-knights, 4 black-pawns, 1 black-queen, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 4 white-rooks, 113.6ms
# Speed: 4.1ms preprocess, 113.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 597.57941, 667.62836), ('white-rook', 151.52954, 242.72151), ('black-pawn', 490.72479, 566.05994), ('black-queen', 368.21436, 896.57281), ('white-pawn', 254.41701, 342.50937), ('black-knight', 934.3313, 567.50513), ('black-rook', 977.43719, 891.21649), ('black-pawn', 839.39685, 781.12482), ('black-knight', 246.56418, 894.46991), ('white-queen', 598.27478, 154.50592), ('black-knight', 950.95331, 784.40643), ('black-rook', 121.61548, 460.76288), ('white-pawn', 597.96356, 557.29974), ('white-knight', 104.12354, 891.73322), ('white-rook', 155.33092, 132.70724), ('white-pawn', 723.74414, 246.82545), ('white-knight', 702.51251, 368.19958), ('white-rook', 810.70215, 458.22232), ('white-king', 369.6199, 254.12088), ('black-pawn', 710.3457, 791.21228), ('white-pawn', 471.29376, 453.05429), ('white-rook', 924.12689, 145.28963), ('black-rook', 951.46271, 785.25208)}
# [('black-pawn', -331.9565, -143.34828), ('white-rook', -2943.3462, -2737.1394), ('black-pawn', -940.964, -746.91986), ('black-queen', -1638.5359, 1181.2544), ('white-pawn', -2324.387, -2111.4526), ('black-knight', 1619.767, -738.2613), ('black-rook', 1787.187, 1150.8177), ('black-pawn', 1031.262, 519.4167), ('black-knight', -2322.5005, 1169.308), ('white-queen', -286.51486, -3299.092), ('black-knight', 1663.3706, 538.3995), ('black-rook', -3087.5522, -1383.3564), ('white-pawn', -321.15326, -799.4487), ('white-knight', -3123.6897, 1153.7551), ('white-rook', -2936.1506, -3439.2534), ('white-pawn', 449.6075, -2711.1997), ('white-knight', 307.5095, -1952.0554), ('white-rook', 925.8697, -1398.8491), ('white-king', -1649.5939, -2665.1318), ('black-pawn', 297.8406, 577.7365), ('white-pawn', -1051.0232, -1430.3845), ('white-rook', 1662.7402, -3358.2878), ('black-rook', 1666.0591, 543.28955)]
#
# 0: 384x416 4 black-knights, 3 black-pawns, 1 black-queen, 3 black-rooks, 1 white-king, 3 white-knights, 4 white-pawns, 1 white-queen, 6 white-rooks, 132.9ms
# Speed: 4.3ms preprocess, 132.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 416)
# {('black-knight', 246.88541, 894.42914), ('white-queen', 598.61041, 154.77208), ('black-knight', 952.16418, 784.72076), ('white-king', 369.689, 254.06644), ('black-pawn', 840.02179, 782.36359), ('black-knight', 489.13269, 904.03833), ('black-queen', 369.61429, 896.75812), ('white-knight', 115.67353, 893.79681), ('white-rook', 702.57117, 368.39105), ('white-rook', 924.39038, 145.44427), ('black-knight', 936.00543, 567.91302), ('white-pawn', 598.07117, 557.66077), ('white-rook', 811.65753, 458.82941), ('white-rook', 155.21708999999998, 133.70708), ('white-rook', 150.77749, 243.0762), ('white-knight', 701.57367, 368.01978), ('white-pawn', 254.46005, 342.56287), ('black-rook', 951.69727, 785.52576), ('black-pawn', 490.8526, 566.2771), ('black-rook', 122.1637, 461.01086), ('white-knight', 104.82761, 892.35309), ('white-pawn', 724.41321, 246.96552), ('white-pawn', 471.93811, 453.44836), ('white-rook', 472.16519, 453.3876), ('black-rook', 977.71338, 891.49249), ('black-pawn', 597.99774, 667.82666)}
# [('black-knight', -2192.2483, 1124.5424), ('white-queen', -294.75314, -3478.2336), ('black-knight', 1681.412, 553.79034), ('white-king', -1659.6827, -2731.4417), ('black-pawn', 1032.4481, 535.1), ('black-knight', -921.97723, 1197.8193), ('black-queen', -1554.3892, 1147.593), ('white-knight', -2861.232, 1110.2472), ('white-rook', 315.24963, -2034.3988), ('white-rook', 1776.1395, -3648.4014), ('black-knight', 1670.3776, -768.13354), ('white-pawn', -319.92285, -810.23303), ('white-rook', 954.4997, -1455.9849), ('white-rook', -2934.6272, -3493.065), ('white-rook', -2915.8171, -2754.6821), ('white-knight', 309.28955, -2036.6948), ('white-pawn', -2298.3958, -2125.8828), ('black-rook', 1678.3723, 558.5018), ('black-pawn', -929.57623, -750.6345), ('black-rook', -2987.3904, -1362.8663), ('white-knight', -2916.4497, 1101.6656), ('white-pawn', 470.77316, -2864.6042), ('white-pawn', -1044.039, -1449.57), ('white-rook', -1042.7435, -1449.9812), ('black-rook', 1787.7854, 1172.856), ('black-pawn', -325.79932, -143.11757)]
#
# 0: 384x416 4 black-knights, 3 black-pawns, 1 black-queen, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 6 white-rooks, 119.9ms
# Speed: 4.3ms preprocess, 119.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('black-knight', 936.39459, 568.01788), ('black-rook', 122.3464, 460.91946), ('white-pawn', 724.58228, 246.88783), ('black-pawn', 491.23154, 566.45697), ('white-queen', 599.87054, 155.03027), ('white-pawn', 598.48224, 557.52014), ('white-rook', 812.38477, 458.6882), ('white-knight', 703.26306, 368.25674), ('black-knight', 247.21333, 894.42206), ('white-knight', 106.56628, 892.62927), ('white-rook', 156.05968000000001, 133.56021), ('white-rook', 151.45067, 243.02512), ('white-rook', 472.97488, 453.62955), ('white-pawn', 473.68311, 453.41785), ('black-knight', 951.09906, 784.82507), ('black-rook', 951.44507, 785.61322), ('black-knight', 489.27921, 904.39154), ('white-rook', 924.88049, 145.4868), ('white-rook', 702.86566, 368.228), ('black-pawn', 840.21289, 782.58136), ('white-pawn', 255.12939, 342.49185), ('black-pawn', 598.81403, 667.71625), ('white-king', 370.60782, 253.98856), ('black-rook', 978.79559, 891.67981), ('black-queen', 488.75043, 904.22644)}
# [('black-knight', 3541.0532, -98.92476), ('black-rook', -1112.4463, -708.59033), ('white-pawn', 2429.6643, -2122.9033), ('black-pawn', 1010.39514, -84.57703), ('white-queen', 1698.4626, -2738.9114), ('white-pawn', 1621.1091, -144.04497), ('white-rook', 2875.2058, -761.1552), ('white-knight', 2267.8354, -1326.5771), ('black-knight', -323.1048, 1795.6932), ('white-knight', -1080.5762, 1792.3917), ('white-rook', -1007.23413, -2858.388), ('white-rook', -1003.86487, -2113.0093), ('white-rook', 911.7056, -773.58075), ('white-pawn', 915.8123, -774.93945), ('black-knight', 3522.9316, 1159.3396), ('black-rook', 3524.4763, 1163.7433), ('black-knight', 980.57745, 1838.5477), ('white-rook', 3685.1091, -2826.1846), ('white-rook', 2265.508, -1326.7382), ('black-pawn', 2914.2441, 1152.0823), ('white-pawn', -366.2271, -1466.0006), ('black-pawn', 1605.6497, 508.0223), ('white-king', 308.74377, -2053.505), ('black-rook', 3625.031, 1747.5242), ('black-queen', 977.7396, 1837.681)]
#
# 0: 384x416 2 black-knights, 4 black-pawns, 1 black-queen, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 7 white-rooks, 107.7ms
# Speed: 4.0ms preprocess, 107.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('white-rook', 925.45892, 145.52899), ('white-rook', 156.19591, 133.66336), ('white-knight', 107.57654, 892.39886), ('white-pawn', 474.00604, 453.35675), ('black-pawn', 599.0647, 667.84808), ('black-knight', 246.46411, 894.30194), ('white-rook', 703.40338, 368.35327), ('black-knight', 936.33026, 568.0968), ('white-pawn', 724.69476, 246.99341), ('white-pawn', 598.94421, 557.41089), ('white-rook', 812.65216, 458.98199), ('black-pawn', 491.32892, 566.58734), ('black-rook', 978.99591, 891.60162), ('black-pawn', 840.43097, 782.23523), ('black-rook', 122.68316, 461.09949), ('black-pawn', 711.73883, 791.13831), ('white-rook', 151.61491, 243.08348), ('black-rook', 951.90051, 785.43921), ('white-king', 370.63892, 254.18268), ('white-knight', 703.85437, 368.41779), ('white-rook', 114.38451, 893.5246), ('white-pawn', 255.17084, 342.59225), ('white-queen', 599.8847, 155.09818), ('white-rook', 473.37802, 453.50342), ('black-queen', 488.76105, 904.43365)}
# [('white-rook', 2306.6553, -1481.2734), ('white-rook', -2133.6223, -1372.2241), ('white-knight', -2432.4756, 3136.3206), ('white-pawn', -388.33698, 511.3748), ('black-pawn', 319.65356, 1829.1101), ('black-knight', -1681.6776, 3169.685), ('white-rook', 949.6073, -34.964367), ('black-knight', 2347.849, 1210.4218), ('white-pawn', 1083.1764, -796.84467), ('white-pawn', 325.1616, 1146.4089), ('white-rook', 1598.4568, 523.5267), ('black-pawn', -295.72272, 1203.863), ('black-rook', 2592.4446, 3278.208), ('black-pawn', 1747.4474, 2563.1697), ('black-rook', -2330.253, 580.1112), ('black-pawn', 974.5866, 2604.0715), ('white-rook', -2163.8164, -719.46295), ('black-rook', 2430.797, 2596.565), ('white-king', -961.2275, -689.8571), ('white-knight', 952.27826, -34.614113), ('white-rook', -2396.1335, 3144.054), ('white-pawn', -1605.6697, -139.39594), ('white-queen', 353.27917, -1342.972), ('white-rook', -391.92142, 512.31396), ('black-queen', -328.8277, 3271.4849)]
#
# 0: 384x416 3 black-knights, 4 black-pawns, 1 black-queen, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 5 white-rooks, 130.5ms
# Speed: 3.8ms preprocess, 130.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('black-rook', 978.45667, 891.34454), ('white-rook', 925.18915, 145.33391), ('black-queen', 369.85681, 896.41913), ('white-pawn', 598.78741, 557.13684), ('white-queen', 600.18036, 154.47884), ('black-pawn', 491.32242, 566.28839), ('white-king', 370.49762, 253.98842), ('black-knight', 247.2173, 894.13965), ('white-pawn', 724.63306, 246.75101), ('white-knight', 703.09027, 368.14252), ('black-pawn', 711.495, 791.0174), ('white-rook', 155.54998, 132.77945), ('black-pawn', 598.71704, 667.75006), ('white-pawn', 255.05292, 342.43192), ('black-knight', 936.45111, 567.69702), ('white-rook', 702.69244, 368.14001), ('white-rook', 151.25214, 242.85262), ('black-pawn', 840.51965, 781.97455), ('black-rook', 122.6793, 460.7247), ('white-pawn', 472.75748, 453.05634), ('black-knight', 951.17987, 784.34131), ('white-knight', 107.59512, 891.66431), ('black-rook', 951.53741, 785.15045), ('white-rook', 812.70532, 458.54108)}
# [('black-rook', 3701.9382, 3100.135), ('white-rook', 3550.4932, -1511.0427), ('black-queen', 342.6242, 3190.1074), ('white-pawn', 1613.9679, 1146.8666), ('white-queen', 1634.2534, -1411.363), ('black-pawn', 1004.19385, 1214.5752), ('white-king', 292.63934, -735.0596), ('black-knight', -332.91812, 3189.115), ('white-pawn', 2357.8772, -823.6017), ('white-knight', 2221.8652, -43.06273), ('black-pawn', 2234.7625, 2540.6423), ('white-rook', -982.62384, -1500.5117), ('black-pawn', 1610.3978, 1818.5573), ('white-pawn', -366.38916, -154.9558), ('black-knight', 3531.2126, 1174.9135), ('white-rook', 2219.5674, -43.03312), ('white-rook', -985.4248, -781.23224), ('black-pawn', 2954.8555, 2474.0857), ('black-rook', -1105.3728, 603.79407), ('white-pawn', 895.1548, 517.02905), ('black-knight', 3571.815, 2476.705), ('white-knight', -1101.689, 3188.6775), ('black-rook', 3573.6519, 2481.446), ('white-rook', 2842.8188, 513.306)]
#
# 0: 384x416 4 black-knights, 4 black-pawns, 1 black-queen, 2 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 4 white-rooks, 115.0ms
# Speed: 4.0ms preprocess, 115.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('black-pawn', 710.98566, 791.05096), ('black-knight', 246.054, 894.28796), ('white-pawn', 724.49908, 246.45584), ('white-rook', 925.16254, 145.312), ('black-rook', 978.19586, 891.20807), ('black-knight', 936.5976, 567.13409), ('white-queen', 599.05408, 154.38103), ('black-queen', 369.34445, 896.53192), ('white-pawn', 471.90326, 452.97748), ('white-rook', 151.20304, 242.53246), ('white-knight', 106.14996, 891.33789), ('white-pawn', 598.6037, 556.97711), ('white-pawn', 254.80186, 342.29581), ('black-rook', 122.20844, 460.25024), ('white-knight', 702.30841, 367.87637), ('white-rook', 155.05318, 132.45596), ('black-knight', 951.73352, 784.0719), ('black-knight', 488.71268, 903.96466), ('black-pawn', 491.07742, 565.87787), ('black-pawn', 839.10498, 781.70819), ('black-pawn', 598.06738, 667.69904), ('white-king', 370.10519, 253.88449000000003), ('white-rook', 811.55756, 457.85117)}
# [('black-pawn', 297.5878, 579.74164), ('black-knight', -2196.5618, 1123.713), ('white-pawn', 471.4057, -2868.1711), ('white-rook', 1781.2502, -3649.6284), ('black-rook', 1790.679, 1171.2836), ('black-knight', 1674.2756, -773.09845), ('white-queen', -291.9952, -3481.1482), ('black-queen', -1555.8368, 1146.3429), ('white-pawn', -1044.2727, -1452.5442), ('white-rook', -2913.639, -2758.3748), ('white-knight', -2910.1436, 1096.363), ('white-pawn', -316.83118, -814.4861), ('white-pawn', -2296.5488, -2127.6643), ('black-rook', -2987.448, -1367.5316), ('white-knight', 313.74832, -2037.7747), ('white-rook', -2936.078, -3501.6162), ('black-knight', 1679.1455, 549.9559), ('black-knight', -924.2196, 1197.3789), ('black-pawn', -928.3306, -753.0823), ('black-pawn', 1027.3627, 531.23816), ('black-pawn', -325.40073, -143.87703), ('white-king', -1657.2922, -2732.759), ('white-rook', 954.1651, -1462.3325)]
#
# 0: 384x416 3 black-knights, 4 black-pawns, 2 black-queens, 2 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 5 white-rooks, 128.9ms
# Speed: 4.1ms preprocess, 128.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 416)
# {('white-knight', 702.81128, 367.89963), ('black-pawn', 839.52612, 780.77521), ('white-pawn', 597.28302, 557.91284), ('white-rook', 151.01701, 242.52489), ('black-pawn', 710.46863, 791.06903), ('white-pawn', 723.31653, 246.70197), ('white-rook', 923.93591, 144.41797), ('black-rook', 977.80762, 891.13916), ('white-knight', 103.40386, 891.68872), ('black-knight', 245.79541, 894.23541), ('white-pawn', 471.68854, 452.87952), ('black-pawn', 490.83414, 565.81696), ('white-king', 369.16077, 253.82034), ('white-pawn', 254.28288, 342.36957), ('black-pawn', 597.51794, 667.57568), ('black-queen', 488.07816, 903.6272), ('black-queen', 369.18042, 896.15369), ('white-rook', 810.6712, 458.1413), ('white-rook', 110.97281, 892.19214), ('white-queen', 598.54138, 154.54393), ('black-knight', 951.58075, 785.0174), ('white-rook', 155.89728, 133.14725), ('black-rook', 121.73071, 460.4743), ('black-knight', 934.62714, 567.31177)}
# [('white-knight', 2192.8008, -22.101614), ('black-pawn', 2857.3608, 2386.4688), ('white-pawn', 1591.3656, 1139.0643), ('white-rook', -1008.0382, -805.51245), ('black-pawn', 2178.249, 2477.0198), ('white-pawn', 2323.1096, -772.5422), ('white-rook', 3440.2646, -1404.7764), ('black-rook', 3541.877, 2964.5886), ('white-knight', -1190.3856, 3235.2207), ('black-knight', -372.58673, 3203.7683), ('white-pawn', 894.64655, 517.5748), ('black-pawn', 999.5799, 1202.8367), ('white-king', 301.53403, -730.07117), ('white-pawn', -372.74115, -159.89432), ('black-pawn', 1583.718, 1788.7516), ('black-queen', 974.29517, 3180.739), ('black-queen', 320.23715, 3175.4644), ('white-rook', 2764.1382, 516.0029), ('white-rook', -1146.3545, 3235.6892), ('white-queen', 1632.8959, -1360.5167), ('black-knight', 3433.6086, 2383.0964), ('white-rook', -994.6975, -1531.3219), ('black-rook', -1151.5316, 601.87244), ('black-knight', 3396.453, 1144.4918)]
#
# 0: 384x416 4 black-knights, 4 black-pawns, 1 black-queen, 2 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 6 white-rooks, 121.9ms
# Speed: 4.1ms preprocess, 121.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('white-rook', 155.07193999999998, 133.50626), ('black-queen', 369.21136, 896.72351), ('black-pawn', 490.75562, 565.93066), ('black-knight', 934.79114, 567.29266), ('black-knight', 488.71637, 903.95435), ('black-knight', 951.88165, 785.18585), ('black-pawn', 597.73773, 667.67249), ('black-pawn', 710.7995, 790.90802), ('white-rook', 810.89886, 458.24008), ('white-rook', 702.51154, 368.05441), ('white-knight', 103.35189, 892.29584), ('black-pawn', 840.07483, 781.10083), ('white-knight', 702.81158, 367.96561), ('black-rook', 977.68073, 891.50696), ('white-pawn', 597.3501, 557.90948), ('black-knight', 246.69296, 894.3252), ('white-queen', 598.51898, 154.78821), ('white-pawn', 471.74832, 453.06125), ('white-pawn', 254.3456, 342.44666), ('white-rook', 150.67922, 242.73224), ('black-rook', 121.87727, 460.77414), ('white-rook', 924.17297, 144.48064), ('white-pawn', 724.14001, 246.70987), ('white-rook', 110.91364, 892.638), ('white-king', 369.14526, 253.70192)}
# [('white-rook', -979.4075, -1495.7822), ('black-queen', 344.60107, 3191.831), ('black-pawn', 1006.6415, 1212.3397), ('black-knight', 3527.5398, 1172.5067), ('black-knight', 1003.21124, 3221.739), ('black-knight', 3581.1455, 2481.517), ('black-pawn', 1610.5164, 1818.0885), ('black-pawn', 2236.467, 2539.9668), ('white-rook', 2838.235, 511.51685), ('white-rook', 2224.3062, -43.66949), ('white-knight', -1119.4031, 3192.6475), ('black-pawn', 2958.077, 2468.8696), ('white-knight', 2226.0469, -44.266857), ('black-rook', 3703.144, 3101.0547), ('white-pawn', 1611.4626, 1151.6506), ('black-knight', -330.27448, 3190.14), ('white-queen', 1630.3522, -1409.2465), ('white-pawn', 895.10254, 517.0607), ('white-pawn', -364.69724, -154.8957), ('white-rook', -982.96313, -782.06085), ('black-rook', -1104.2323, 604.0796), ('white-rook', 3550.5725, -1516.6768), ('white-pawn', 2360.8418, -823.92804), ('white-rook', -1077.7374, 3193.873), ('white-king', 290.56223, -736.8689)]
#
# 0: 384x416 4 black-knights, 3 black-pawns, 1 black-queen, 3 black-rooks, 1 white-king, 3 white-knights, 4 white-pawns, 1 white-queen, 6 white-rooks, 119.8ms
# Speed: 3.8ms preprocess, 119.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('black-knight', 951.28131, 784.55646), ('white-pawn', 598.72125, 557.24097), ('white-knight', 703.6217, 368.40396), ('black-pawn', 598.53436, 667.66174), ('black-knight', 488.29855, 904.33783), ('white-rook', 703.23773, 368.33994), ('black-rook', 951.61676, 785.33356), ('black-knight', 936.68341, 567.68835), ('black-rook', 122.37006, 461.27371), ('white-rook', 811.92999, 458.69775), ('black-pawn', 491.11761, 566.16016), ('black-queen', 369.66373, 896.99744), ('white-rook', 924.88, 145.42336), ('white-pawn', 723.72479, 246.90359), ('white-pawn', 255.12004, 342.74765), ('white-rook', 151.07535000000001, 243.45546), ('white-pawn', 472.53653, 453.29526), ('white-rook', 471.90042, 453.31891), ('black-rook', 978.59503, 891.67603), ('white-rook', 155.00261999999998, 133.59125), ('black-knight', 246.75755, 894.16455), ('white-knight', 105.09196, 892.61108), ('white-knight', 115.90747, 893.90106), ('black-pawn', 840.30463, 782.12463), ('white-king', 370.10583, 254.2868), ('white-queen', 598.89423, 155.11632)}
# [('black-knight', 1675.12, 536.8406), ('white-pawn', -309.83307, -793.64465), ('white-knight', 309.97253, -1963.7185), ('black-pawn', -319.24265, -139.56381), ('black-knight', -933.6043, 1217.2443), ('white-rook', 307.7466, -1964.0337), ('black-rook', 1676.8882, 541.4401), ('black-knight', 1642.8278, -770.15894), ('black-rook', -2902.3916, -1296.1149), ('white-rook', 929.07074, -1424.0552), ('black-pawn', -910.1182, -728.3321), ('black-queen', -1564.7876, 1171.1978), ('white-rook', 1678.9263, -3458.0635), ('white-pawn', 444.6761, -2734.6213), ('white-pawn', -2207.581, -2023.607), ('white-rook', -2779.4055, -2599.1946), ('white-pawn', -1010.69196, -1399.419), ('white-rook', -1014.2289, -1399.1707), ('black-rook', 1807.3579, 1166.6962), ('white-rook', -2772.6917, -3273.649), ('black-knight', -2206.8835, 1150.5771), ('white-knight', -2932.1304, 1136.5942), ('white-knight', -2877.1548, 1144.0293), ('black-pawn', 1032.9512, 523.5018), ('white-king', -1581.64, -2590.714), ('white-queen', -276.98053, -3282.7466)]
#
# 0: 384x416 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 7 white-rooks, 121.7ms
# Speed: 4.0ms preprocess, 121.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 416)
# {('white-king', 370.33707, 254.19926), ('white-pawn', 472.87619, 453.383), ('black-rook', 979.00525, 891.54083), ('white-knight', 106.77908, 892.61755), ('black-knight', 246.76009, 894.4563), ('white-pawn', 599.06604, 557.11188), ('white-pawn', 724.87622, 246.88759), ('white-rook', 703.59216, 368.03726), ('white-rook', 925.09979, 145.467), ('white-queen', 600.19672, 155.30028), ('black-knight', 936.76947, 567.71167), ('white-pawn', 254.99086, 343.16293), ('black-pawn', 599.13562, 667.6568), ('white-rook', 114.62611, 893.77808), ('white-rook', 812.48657, 458.69281), ('black-rook', 951.27399, 785.44043), ('black-pawn', 491.65958, 566.25604), ('white-rook', 151.92166, 243.38017), ('black-pawn', 840.7085, 782.1441), ('black-rook', 122.5067, 461.51215), ('white-rook', 155.56165, 133.07866), ('white-rook', 472.37982, 453.6264), ('black-pawn', 711.7428, 791.41937), ('white-knight', 704.1394, 368.01712)}
# [('white-king', -1737.2953, -2772.6013), ('white-pawn', -1080.977, -1459.2704), ('black-rook', 1773.6842, 1129.2211), ('white-knight', -3050.0955, 1177.059), ('black-knight', -2277.009, 1180.55), ('white-pawn', -331.21927, -813.5082), ('white-pawn', 443.06958, -2846.0981), ('white-rook', 298.80914, -2028.1376), ('white-rook', 1713.6937, -3570.752), ('white-queen', -324.95724, -3478.248), ('black-knight', 1639.4232, -767.00085), ('white-pawn', -2412.7979, -2164.9038), ('black-pawn', -330.6153, -141.65121), ('white-rook', -3006.316, 1183.1141), ('white-rook', 936.4442, -1445.4161), ('black-rook', 1652.8955, 530.24945), ('black-pawn', -957.2909, -750.96466), ('white-rook', -3082.7593, -2832.5393), ('black-pawn', 1030.4567, 516.87744), ('black-rook', -3155.2976, -1386.5924), ('white-rook', -3114.3042, -3605.851), ('white-rook', -1083.893, -1457.6821), ('black-pawn', 302.7861, 576.70404), ('white-knight', 302.11276, -2028.3044)]
#
# 0: 384x416 2 black-knights, 4 black-pawns, 3 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 5 white-rooks, 127.6ms
# Speed: 4.0ms preprocess, 127.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('white-pawn', 472.68539, 453.27716), ('white-pawn', 254.92439, 342.90741), ('black-rook', 978.9137, 891.28888), ('black-knight', 247.59836, 894.39496), ('white-pawn', 599.14789, 557.00385), ('black-knight', 936.82672, 567.67401), ('white-rook', 925.19122, 145.30327), ('black-rook', 952.31409, 785.26001), ('white-pawn', 724.84497, 246.84579), ('white-rook', 703.58313, 368.25262), ('black-pawn', 599.0517, 667.71948), ('black-pawn', 841.01575, 781.87024), ('white-queen', 600.06628, 154.98439), ('black-rook', 122.56963, 461.28873), ('black-pawn', 491.61301, 566.20557), ('white-knight', 108.3515, 891.9931), ('white-king', 370.51764, 254.04448), ('white-knight', 704.09949, 368.28821), ('white-rook', 151.96282, 243.32193), ('white-rook', 155.57024, 133.11873), ('black-pawn', 711.75531, 791.33954), ('white-rook', 812.48285, 458.56403)}
# [('white-pawn', 889.39996, -758.2508), ('white-pawn', -362.51917, -1443.2283), ('black-rook', 3527.0518, 1698.1299), ('black-knight', -330.37927, 1849.5714), ('white-pawn', 1585.5289, -143.501), ('black-knight', 3369.3047, -95.77676), ('white-rook', 3380.7751, -2592.8137), ('black-rook', 3411.6948, 1123.2815), ('white-pawn', 2286.8372, -1997.3344), ('white-rook', 2161.4895, -1263.4062), ('black-pawn', 1582.0687, 500.29797), ('black-pawn', 2845.1443, 1119.29), ('white-queen', 1601.8295, -2582.3105), ('black-rook', -1118.8071, -711.3167), ('black-pawn', 997.336, -84.73685), ('white-knight', -1115.2563, 1863.1113), ('white-king', 298.4382, -1990.314), ('white-knight', 2164.286, -1263.1685), ('white-rook', -987.581, -2082.8855), ('white-rook', -987.5012, -2795.7476), ('black-pawn', 2173.86, 1189.753), ('white-rook', 2735.985, -724.7498)]
#
# 0: 384x416 4 black-knights, 4 black-pawns, 1 black-queen, 2 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 5 white-rooks, 120.4ms
# Speed: 4.2ms preprocess, 120.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# {('white-pawn', 472.43686, 453.02069), ('black-knight', 246.84445, 894.57727), ('black-knight', 951.40839, 784.35541), ('white-rook', 924.38776, 144.09128), ('white-king', 370.61499, 253.60096999999996), ('white-rook', 702.44537, 367.99081), ('white-rook', 811.86176, 458.34213), ('black-rook', 122.55475, 460.57162), ('black-rook', 978.2309, 891.25549), ('black-pawn', 491.33344, 566.0423), ('white-pawn', 254.67395, 342.37143), ('white-queen', 600.17444, 154.60207), ('white-pawn', 723.90796, 246.70212), ('black-pawn', 711.41553, 791.1687), ('black-pawn', 840.21747, 781.82422), ('black-queen', 369.75104, 896.4809), ('black-pawn', 598.53436, 667.67627), ('white-rook', 151.50182999999998, 242.76741), ('white-knight', 702.86493, 367.90115), ('black-knight', 936.62738, 567.58344), ('white-knight', 108.75793, 891.51453), ('black-knight', 489.28848, 904.14209), ('white-rook', 155.43110000000001, 132.50935), ('white-pawn', 598.77667, 557.1001)}
# [('white-pawn', 0.0, 0.0), ('black-knight', 0.0, 0.0), ('black-knight', 0.0, 0.0), ('white-rook', 0.0, 0.0), ('white-king', 0.0, 0.0), ('white-rook', 0.0, 0.0), ('white-rook', 0.0, 0.0), ('black-rook', 0.0, 0.0), ('black-rook', 0.0, 0.0), ('black-pawn', 0.0, 0.0), ('white-pawn', 0.0, 0.0), ('white-queen', 0.0, 0.0), ('white-pawn', 0.0, 0.0), ('black-pawn', 0.0, 0.0), ('black-pawn', 0.0, 0.0), ('black-queen', 0.0, 0.0), ('black-pawn', 0.0, 0.0), ('white-rook', 0.0, 0.0), ('white-knight', 0.0, 0.0), ('black-knight', 0.0, 0.0), ('white-knight', 0.0, 0.0), ('black-knight', 0.0, 0.0), ('white-rook', 0.0, 0.0), ('white-pawn', 0.0, 0.0)]
#
# 0: 384x416 4 black-knights, 4 black-pawns, 1 black-queen, 2 black-rooks, 1 white-king, 2 white-knights, 4 white-pawns, 1 white-queen, 5 white-rooks, 132.6ms
# Speed: 4.2ms preprocess, 132.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 416)
# ...
# disappeared: {('black', 'rook', 'e', '2'), ('white', 'knight', 'd', '1'), ('black', 'queen', 'd', '1'), ('white', 'rook', 'c', '3'), ('white', 'pawn', 'd', '3'), ('black', 'pawn', 'd', '2'), ('black', 'rook', 'f', '4'), ('white', 'rook', 'h', '7'), ('white', 'pawn', 'a', '6'), ('black', 'knight', 'd', '1'), ('black', 'knight', 'a', '1'), ('white', 'queen', 'c', '4'), ('white', 'rook', 'h', '1'), ('black', 'rook', 'f', '2'), ('white', 'pawn', 'f', '2'), ('white', 'king', 'c', '4'), ('white', 'rook', 'd', '2'), ('white', 'queen', 'e', '3'), ('white', 'rook', 'e', '1'), ('white', 'knight', 'e', '1'), ('black', 'pawn', 'd', '1'), ('black', 'pawn', 'e', '2')}
# l_a: 9
# l_d: 22
# appeared: {('white', 'rook', 'd', '3'), ('black', 'rook', 'e', '2'), ('white', 'knight', 'd', '1'), ('black', 'queen', 'd', '1'), ('white', 'rook', 'e', '2'), ('white', 'queen', 'e', '2'), ('black', 'knight', 'e', '2'), ('black', 'pawn', 'd', '2'), ('white', 'pawn', 'f', '2'), ('white', 'queen', 'd', '2'), ('white', 'king', 'd', '2'), ('white', 'rook', 'd', '2'), ('white', 'rook', 'c', '2'), ('white', 'pawn', 'd', '2'), ('black', 'rook', 'g', '2'), ('black', 'knight', 'c', '2'), ('black', 'pawn', 'd', '1'), ('black', 'pawn', 'e', '2'), ('white', 'rook', 'b', '2'), ('black', 'rook', 'b', '2')}
# disappeared: {('white', 'knight', 'a', '8'), ('black', 'rook', 'a', '8'), ('black', 'pawn', 'a', '8'), ('white', 'rook', 'a', '8'), ('black', 'queen', 'a', '8'), ('black', 'knight', 'a', '8'), ('white', 'king', 'a', '8'), ('white', 'queen', 'a', '8'), ('white', 'pawn', 'a', '8')}
# l_a: 20
# l_d: 9
# appeared: {('white', 'knight', 'a', '8'), ('black', 'rook', 'a', '8'), ('black', 'pawn', 'a', '8'), ('white', 'rook', 'a', '8'), ('black', 'queen', 'a', '8'), ('black', 'knight', 'a', '8'), ('white', 'king', 'a', '8'), ('white', 'queen', 'a', '8'), ('white', 'pawn', 'a', '8')}
# disappeared: {('white', 'rook', 'd', '3'), ('black', 'rook', 'e', '2'), ('white', 'knight', 'd', '1'), ('black', 'queen', 'd', '1'), ('white', 'rook', 'e', '2'), ('white', 'queen', 'e', '2'), ('black', 'knight', 'e', '2'), ('black', 'pawn', 'd', '2'), ('white', 'pawn', 'f', '2'), ('white', 'queen', 'd', '2'), ('white', 'king', 'd', '2'), ('white', 'rook', 'd', '2'), ('white', 'rook', 'c', '2'), ('white', 'pawn', 'd', '2'), ('black', 'rook', 'g', '2'), ('black', 'knight', 'c', '2'), ('black', 'pawn', 'd', '1'), ('black', 'pawn', 'e', '2'), ('white', 'rook', 'b', '2'), ('black', 'rook', 'b', '2')}
# l_a: 9
# l_d: 20
# appeared: {('white', 'rook', 'e', '3'), ('black', 'rook', 'e', '2'), ('black', 'rook', 'g', '2'), ('white', 'knight', 'd', '1'), ('black', 'pawn', 'd', '1'), ('white', 'rook', 'f', '1'), ('white', 'queen', 'e', '1'), ('white', 'pawn', 'e', '1'), ('black', 'pawn', 'e', '2'), ('black', 'queen', 'e', '2'), ('white', 'rook', 'd', '2'), ('white', 'king', 'e', '1'), ('black', 'rook', 'e', '1'), ('black', 'knight', 'e', '3'), ('white', 'knight', 'd', '3'), ('black', 'knight', 'e', '2'), ('white', 'pawn', 'f', '2'), ('white', 'pawn', 'e', '2')}
# disappeared: {('white', 'knight', 'a', '8'), ('black', 'rook', 'a', '8'), ('black', 'pawn', 'a', '8'), ('white', 'rook', 'a', '8'), ('black', 'queen', 'a', '8'), ('black', 'knight', 'a', '8'), ('white', 'king', 'a', '8'), ('white', 'queen', 'a', '8'), ('white', 'pawn', 'a', '8')}
# l_a: 18
# l_d: 9
# appeared: {('black', 'pawn', 'h', '3'), ('white', 'rook', 'e', '2'), ('white', 'rook', 'e', '8'), ('white', 'knight', 'f', '4'), ('white', 'rook', 'f', '4'), ('black', 'rook', 'a', '1'), ('black', 'knight', 'a', '3'), ('white', 'knight', 'e', '8'), ('white', 'queen', 'e', '2'), ('white', 'rook', 'c', '1'), ('black', 'knight', 'g', '6'), ('black', 'rook', 'a', '2'), ('white', 'queen', 'd', '2'), ('black', 'rook', 'd', '8'), ('white', 'king', 'd', '2'), ('white', 'rook', 'g', '4'), ('black', 'pawn', 'd', '7'), ('black', 'pawn', 'd', '6'), ('white', 'pawn', 'd', '2'), ('white', 'pawn', 'd', '8'), ('white', 'pawn', 'f', '3')}
# disappeared: {('black', 'rook', 'e', '2'), ('black', 'rook', 'g', '2'), ('white', 'knight', 'd', '1'), ('black', 'pawn', 'd', '1'), ('white', 'rook', 'f', '1'), ('white', 'queen', 'e', '1'), ('white', 'pawn', 'e', '1'), ('black', 'queen', 'e', '2'), ('white', 'rook', 'd', '2'), ('white', 'king', 'e', '1'), ('black', 'rook', 'e', '1'), ('black', 'knight', 'e', '3'), ('white', 'knight', 'd', '3'), ('black', 'knight', 'e', '2'), ('white', 'pawn', 'f', '2'), ('white', 'pawn', 'e', '2')}
# l_a: 21
# l_d: 16
# appeared: {('white', 'rook', 'd', '3'), ('black', 'rook', 'e', '2'), ('black', 'rook', 'g', '2'), ('white', 'knight', 'd', '1'), ('black', 'knight', 'c', '2'), ('black', 'pawn', 'd', '1'), ('white', 'knight', 'b', '2'), ('white', 'rook', 'd', '2'), ('white', 'rook', 'b', '2'), ('black', 'rook', 'b', '2'), ('white', 'rook', 'c', '2'), ('black', 'knight', 'e', '2'), ('black', 'pawn', 'd', '2'), ('white', 'pawn', 'f', '2')}
# disappeared: {('white', 'rook', 'e', '3'), ('white', 'pawn', 'd', '8'), ('black', 'pawn', 'h', '3'), ('white', 'rook', 'c', '1'), ('black', 'rook', 'd', '8'), ('white', 'rook', 'g', '4'), ('white', 'rook', 'e', '8'), ('white', 'knight', 'f', '4'), ('black', 'pawn', 'd', '7'), ('white', 'rook', 'f', '4'), ('black', 'rook', 'a', '1'), ('black', 'knight', 'a', '3'), ('white', 'knight', 'e', '8'), ('white', 'pawn', 'f', '3'), ('black', 'knight', 'g', '6'), ('black', 'pawn', 'd', '6'), ('black', 'rook', 'a', '2')}
# l_a: 14
# l_d: 17
# appeared: {('white', 'rook', 'e', '3'), ('black', 'knight', 'd', '1'), ('white', 'rook', 'h', '2'), ('white', 'queen', 'e', '1'), ('white', 'knight', 'g', '2'), ('white', 'king', 'e', '1'), ('white', 'rook', 'd', '8'), ('white', 'pawn', 'f', '1'), ('black', 'knight', 'b', '2'), ('white', 'queen', 'e', '8'), ('white', 'rook', 'd', '1'), ('black', 'rook', 'a', '3'), ('white', 'pawn', 'e', '2')}
# disappeared: {('black', 'knight', 'c', '2'), ('white', 'knight', 'd', '1'), ('white', 'queen', 'd', '2'), ('white', 'king', 'd', '2'), ('white', 'knight', 'b', '2'), ('white', 'rook', 'e', '2'), ('white', 'rook', 'b', '2'), ('black', 'rook', 'b', '2'), ('white', 'queen', 'e', '2'), ('white', 'rook', 'c', '2'), ('black', 'knight', 'e', '2'), ('white', 'pawn', 'f', '2')}
# l_a: 13
# l_d: 12
# appeared: {('white', 'rook', 'f', '1'), ('black', 'knight', 'a', '1'), ('black', 'rook', 'f', '2'), ('white', 'rook', 'h', '8'), ('white', 'king', 'c', '4'), ('white', 'knight', 'f', '1'), ('white', 'queen', 'e', '3'), ('white', 'rook', 'c', '3'), ('white', 'pawn', 'd', '3'), ('white', 'rook', 'e', '1'), ('black', 'rook', 'f', '4'), ('white', 'rook', 'h', '7'), ('white', 'pawn', 'a', '6'), ('white', 'pawn', 'f', '2')}
# disappeared: {('white', 'rook', 'e', '3'), ('white', 'rook', 'd', '3'), ('black', 'rook', 'g', '2'), ('white', 'rook', 'h', '2'), ('white', 'queen', 'e', '1'), ('white', 'knight', 'g', '2'), ('white', 'king', 'e', '1'), ('white', 'rook', 'd', '8'), ('white', 'pawn', 'f', '1'), ('black', 'knight', 'b', '2'), ('white', 'queen', 'e', '8'), ('white', 'rook', 'd', '1'), ('black', 'rook', 'a', '3'), ('white', 'pawn', 'e', '2'), ('white', 'pawn', 'd', '2')}
# l_a: 14
# l_d: 15
# appeared: {('white', 'knight', 'd', '1'), ('white', 'pawn', 'c', '3')}
# disappeared: set()
# l_a: 2
# l_d: 0
# appeared: {('white', 'rook', 'd', '3'), ('black', 'rook', 'g', '2'), ('black', 'knight', 'c', '2'), ('white', 'king', 'd', '2'), ('white', 'knight', 'b', '2'), ('white', 'rook', 'e', '2'), ('white', 'rook', 'b', '2'), ('black', 'rook', 'b', '2'), ('white', 'queen', 'e', '2'), ('white', 'rook', 'c', '2'), ('black', 'knight', 'e', '2'), ('white', 'pawn', 'd', '2')}
# disappeared: {('black', 'knight', 'd', '1'), ('black', 'knight', 'a', '1'), ('black', 'rook', 'f', '2'), ('white', 'rook', 'h', '8'), ('white', 'king', 'c', '4'), ('white', 'knight', 'f', '1'), ('white', 'queen', 'e', '3'), ('white', 'rook', 'c', '3'), ('white', 'pawn', 'd', '3'), ('white', 'rook', 'e', '1'), ('black', 'rook', 'f', '4'), ('white', 'rook', 'h', '7'), ('white', 'pawn', 'a', '6'), ('white', 'rook', 'f', '1'), ('white', 'pawn', 'c', '3')}
# l_a: 12
# l_d: 15
# appeared: {('white', 'knight', 'a', '8'), ('black', 'rook', 'a', '8'), ('black', 'pawn', 'a', '8'), ('white', 'rook', 'a', '8'), ('black', 'knight', 'a', '8'), ('white', 'king', 'a', '8'), ('white', 'queen', 'a', '8'), ('white', 'pawn', 'a', '8')}
# disappeared: {('white', 'rook', 'd', '3'), ('black', 'rook', 'e', '2'), ('white', 'knight', 'd', '1'), ('white', 'rook', 'e', '2'), ('white', 'queen', 'e', '2'), ('black', 'knight', 'e', '2'), ('black', 'pawn', 'd', '2'), ('white', 'pawn', 'f', '2'), ('white', 'king', 'd', '2'), ('white', 'rook', 'd', '2'), ('white', 'rook', 'c', '2'), ('white', 'pawn', 'd', '2'), ('black', 'rook', 'g', '2'), ('black', 'knight', 'c', '2'), ('black', 'pawn', 'd', '1'), ('white', 'knight', 'b', '2'), ('black', 'pawn', 'e', '2'), ('white', 'rook', 'b', '2'), ('black', 'rook', 'b', '2')}
# l_a: 8
# l_d: 19
# appeared: {('black', 'rook', 'e', '2'), ('white', 'king', 'd', '3'), ('white', 'rook', 'e', '2'), ('white', 'rook', 'c', '3'), ('white', 'pawn', 'd', '3'), ('white', 'queen', 'e', '2'), ('black', 'pawn', 'd', '2'), ('white', 'rook', 'b', '6'), ('black', 'rook', 'h', '3'), ('white', 'rook', 'h', '1'), ('black', 'rook', 'f', '2'), ('white', 'pawn', 'f', '2'), ('black', 'knight', 'b', '1'), ('white', 'pawn', 'c', '4'), ('white', 'rook', 'd', '2'), ('white', 'rook', 'b', '4'), ('black', 'knight', 'd', '2'), ('black', 'pawn', 'd', '1'), ('black', 'pawn', 'e', '2')}
# disappeared: {('white', 'knight', 'a', '8'), ('black', 'rook', 'a', '8'), ('black', 'pawn', 'a', '8'), ('white', 'rook', 'a', '8'), ('black', 'knight', 'a', '8'), ('white', 'king', 'a', '8'), ('white', 'queen', 'a', '8'), ('white', 'pawn', 'a', '8')}
# l_a: 19
# l_d: 8
# appeared: {('white', 'king', 'b', '4'), ('white', 'pawn', 'f', '4'), ('white', 'queen', 'd', '4'), ('white', 'queen', 'b', '4'), ('white', 'rook', 'h', '6'), ('white', 'rook', 'h', '8'), ('black', 'knight', 'c', '1'), ('white', 'rook', 'f', '4'), ('white', 'pawn', 'a', '5'), ('white', 'knight', 'h', '1'), ('black', 'knight', 'e', '2'), ('white', 'rook', 'a', '1'), ('black', 'rook', 'g', '3')}
# disappeared: {('white', 'king', 'd', '3'), ('white', 'rook', 'b', '6'), ('black', 'knight', 'b', '1'), ('white', 'pawn', 'c', '4'), ('black', 'rook', 'h', '3'), ('white', 'rook', 'e', '2'), ('white', 'rook', 'b', '4'), ('white', 'rook', 'h', '1'), ('black', 'knight', 'd', '2'), ('white', 'queen', 'e', '2'), ('white', 'pawn', 'f', '2')}
# l_a: 13
# l_d: 11
# appeared: {('white', 'queen', 'd', '5')}
# disappeared: {('white', 'rook', 'a', '1'), ('white', 'queen', 'd', '4')}
# l_a: 1
# l_d: 2
# triggered case 2
# appeared: {('white', 'knight', 'a', '8'), ('black', 'rook', 'a', '8'), ('black', 'pawn', 'a', '8'), ('white', 'rook', 'a', '8'), ('black', 'knight', 'a', '8'), ('white', 'queen', 'a', '8'), ('white', 'pawn', 'a', '8')}
# disappeared: {('black', 'rook', 'e', '2'), ('white', 'rook', 'f', '4'), ('white', 'rook', 'c', '3'), ('white', 'pawn', 'd', '3'), ('black', 'knight', 'e', '2'), ('black', 'pawn', 'd', '2'), ('black', 'rook', 'g', '3'), ('white', 'pawn', 'f', '4'), ('white', 'rook', 'h', '6'), ('black', 'knight', 'c', '1'), ('white', 'knight', 'h', '1'), ('black', 'rook', 'f', '2'), ('white', 'queen', 'd', '5'), ('white', 'queen', 'b', '4'), ('white', 'rook', 'd', '2'), ('white', 'pawn', 'a', '5'), ('white', 'king', 'b', '4'), ('black', 'pawn', 'd', '1'), ('white', 'rook', 'h', '8'), ('black', 'pawn', 'e', '2')}
# l_a: 7
# l_d: 20
# appeared: {('black', 'queen', 'a', '8')}
# disappeared: set()
# l_a: 1
# l_d: 0
# appeared: {('black', 'rook', 'e', '2'), ('black', 'knight', 'c', '2'), ('white', 'knight', 'd', '1'), ('black', 'rook', 'g', '2'), ('black', 'pawn', 'd', '1'), ('white', 'knight', 'b', '2'), ('black', 'pawn', 'e', '2'), ('white', 'rook', 'e', '2'), ('white', 'rook', 'd', '2'), ('black', 'rook', 'b', '2'), ('white', 'queen', 'e', '2'), ('white', 'rook', 'c', '2'), ('black', 'knight', 'e', '2'), ('black', 'pawn', 'd', '2'), ('black', 'queen', 'd', '2'), ('white', 'pawn', 'f', '2'), ('white', 'pawn', 'd', '2')}
# disappeared: {('white', 'knight', 'a', '8'), ('black', 'rook', 'a', '8'), ('black', 'pawn', 'a', '8'), ('white', 'rook', 'a', '8'), ('black', 'queen', 'a', '8'), ('black', 'knight', 'a', '8'), ('white', 'queen', 'a', '8'), ('white', 'pawn', 'a', '8')}
# l_a: 17
# l_d: 8
# appeared: {('black', 'king', 'd', '2')}
# disappeared: set()
# l_a: 1
# l_d: 0
# appeared: {('black', 'rook', 'g', '3'), ('white', 'pawn', 'f', '4'), ('white', 'queen', 'd', '4'), ('white', 'rook', 'e', '4'), ('black', 'knight', 'c', '1'), ('white', 'rook', 'f', '4'), ('white', 'rook', 'c', '3'), ('white', 'pawn', 'd', '3'), ('white', 'knight', 'h', '1'), ('white', 'knight', 'd', '2'), ('black', 'rook', 'f', '2'), ('white', 'rook', 'a', '1'), ('white', 'pawn', 'c', '3')}
# disappeared: {('black', 'rook', 'g', '2'), ('black', 'knight', 'c', '2'), ('white', 'knight', 'd', '1'), ('white', 'knight', 'b', '2'), ('white', 'rook', 'e', '2'), ('black', 'rook', 'b', '2'), ('white', 'queen', 'e', '2'), ('white', 'rook', 'c', '2'), ('black', 'king', 'd', '2'), ('black', 'queen', 'd', '2'), ('white', 'pawn', 'f', '2'), ('white', 'pawn', 'd', '2')}
# l_a: 13
# l_d: 12
# appeared: {('white', 'queen', 'd', '5'), ('black', 'queen', 'd', '1')}
# disappeared: {('white', 'knight', 'd', '2'), ('white', 'rook', 'a', '1'), ('white', 'queen', 'd', '4'), ('white', 'rook', 'e', '4')}
# l_a: 2
# l_d: 4
# appeared: {('white', 'rook', 'a', '1')}
# disappeared: {('white', 'pawn', 'c', '3'), ('black', 'pawn', 'd', '1')}
# l_a: 1
# l_d: 2
# triggered case 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> pgn, boards = main("2_move_student.mp4")
#
# /home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb Cell 12 line 2
#     <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X40sZmlsZQ%3D%3D?line=256'>257</a> differences = summarize_states(lst=state_list, tolerance=TOLERANCE)
#     <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X40sZmlsZQ%3D%3D?line=257'>258</a> print("differences:", differences)
# --> <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X40sZmlsZQ%3D%3D?line=258'>259</a> uci = uci_from_differences(differences)
#     <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X40sZmlsZQ%3D%3D?line=259'>260</a> pgn, board_states = generate_pgn(moves=uci, ori=ori)
#     <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X40sZmlsZQ%3D%3D?line=261'>262</a> return pgn, board_states
#
# /home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb Cell 12 line 1
#     <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X40sZmlsZQ%3D%3D?line=112'>113</a>     print("triggered case 2")
#     <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X40sZmlsZQ%3D%3D?line=114'>115</a>     new = list(appeared)[0]
# --> <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X40sZmlsZQ%3D%3D?line=115'>116</a>     old = [piece for piece in disappeared if piece[:2] == new[:2]][0] # the capturer
#     <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X40sZmlsZQ%3D%3D?line=117'>118</a>     msg = f"{old[2]}{old[3]}{new[2]}{new[3]}"
#     <a href='vscode-notebook-cell:/home/gems/Documents/Chess-Detection-Project/AI_boys.ipynb#X40sZmlsZQ%3D%3D?line=119'>120</a> elif l_d == 2 and l_a == 2: # castling
#
# IndexError: list index out of range

# %%
for i in boards:
    print(i)
# Out:
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . r p . . .
# . . r k r r . .
# . . n n p . . .
